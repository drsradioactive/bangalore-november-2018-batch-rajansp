# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline

# Numerical libraries
import numpy as np   



# to handle data in form of rows and columns 
import pandas as pd    

# importing ploting libraries
import matplotlib.pyplot as plt   
import matplotlib.style
plt.style.use('classic')

#importing seaborn for statistical plots
import seaborn as sns

# %%
Park_df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/parkinsons.data')
Park_df.head()
Park_df.tail()
Park_df.shape
Park_df.dtypes
Park_df.info
Park_df.isnull().values.any()
Park_df.isnull().sum().sum()
Park_df.isna().values.any()
Park_df.isna().sum().sum()
Park_df.describe()
Park_df.describe().transpose()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer    ...     \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374    ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134    ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233    ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492    ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425    ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
#no missing values
#no NaN values

# %%
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:Fo(Hz)")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:Fhi(Hz)")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:Flo(Hz)")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:Jitter(%)")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:Jitter(Abs)")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:RAP")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:PPQ")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"Jitter:DDP")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:Shimmer")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:Shimmer(dB)")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"Shimmer:APQ3")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"Shimmer:APQ5")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"MDVP:APQ")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"Shimmer:DDA")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"NHR")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"HNR")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"RPDE")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"DFA")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"spread1")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"spread2")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"D2")
sns.FacetGrid(Park_df,hue="status",size=5).map(sns.distplot,"PPE")
# Out:
# C:\Users\rajan\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\rajan\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\rajan\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\rajan\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#most of the variables do not have perfect normal distrution and with very few variables has a clear distinction for the 
#status class. COmbination of variables could be used to predit the status class better

# %%
sns.boxplot(x="status", y="MDVP:Fo(Hz)",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:Fo(Hz)",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="MDVP:Fhi(Hz)",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:Fhi(Hz)",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#MDVP:Fhi(Hz) has a lot of outliers for the status 1, so outlier treatment is required

# %%
sns.boxplot(x="status",y="MDVP:Flo(Hz)",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:Flo(Hz)",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="MDVP:Jitter(%)",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:Jitter(%)",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#MDVP:Jitter(%) can be a good predictor for the status class but outlier treatment is required.

# %%
sns.boxplot(x="status",y="MDVP:Jitter(Abs)",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:Jitter(Abs)",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#MDVP:Jitter(Abs) can be a good predictor for the status class but outlier treatment is required.

# %%
sns.boxplot(x="status",y="MDVP:RAP",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:RAP",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#MDVP:RAP is  a good predictor for the status class but outlier treatment is required.

# %%
sns.boxplot(x="status",y="MDVP:PPQ",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:PPQ",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#MDVP:PPQ looks like a good predictor of status class because of the right skew of class 1

# %%
sns.boxplot(x="status",y="Jitter:DDP",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="Jitter:DDP",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Jitter:DDP looks like a good predictor of status class because of the right skew of class 1

# %%
sns.boxplot(x="status",y="Jitter:DDP",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="Jitter:DDP",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="MDVP:Shimmer",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:Shimmer",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="MDVP:Shimmer(dB)",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:Shimmer(dB)",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="Shimmer:APQ3",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="Shimmer:APQ3",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="Shimmer:APQ5",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="Shimmer:APQ5",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="MDVP:APQ",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="MDVP:APQ",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="Shimmer:DDA",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Shimmer:DDA is a good predictor of status class but have outliers which needs to be treated

# %%
sns.violinplot(x="status",y="Shimmer:DDA",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="NHR",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="NHR",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#NHR has lot of outliers for the status class

# %%
sns.boxplot(x="status",y="HNR",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="HNR",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#HNR has outliers for both the status class with class 0 is righ and class 1 is left skewed

# %%
sns.boxplot(x="status",y="RPDE",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="RPDE",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#RPDE variable looks clean to use for the model

# %%
sns.boxplot(x="status",y="DFA",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="DFA",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#DFA variable looks clean to use for the model

# %%
sns.boxplot(x="status",y="spread1",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="spread1",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#spread1 variable looks clean to use for the model and will be good separator for the status class with some 
#outliers present for the class 1

# %%
sns.boxplot(x="status",y="spread2",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="spread2",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#spread2 variable looks clean to use for the model and will be good separator for the status class with some 
#outliers present for the class 1 and looks like a compleentary variable to spread1

# %%
sns.boxplot(x="status",y="D2",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="D2",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.boxplot(x="status",y="PPE",data=Park_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.violinplot(x="status",y="PPE",data=Park_df,size=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.pairplot(Park_df,diag_kind='kde', hue="status")
# Out:
# C:\Users\rajan\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\rajan\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\rajan\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
Park_df= Park_df.drop(labels = "name", axis = 1)

x = Park_df.drop("status", axis=1)
Y = Park_df[['status']]
x.shape
Y.shape
# Out:
# (195, 22)
# (195, 1)

# %%
from scipy.stats import zscore
X = x.apply(zscore)
X.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0    -0.829300     -0.436165     -0.952037        0.334914          0.749759
# 1    -0.770972     -0.530974     -0.057721        0.715418          1.037674
# 2    -0.909476     -0.723168     -0.109875        0.884991          1.325589
# 3    -0.909622     -0.649092     -0.114229        0.775389          1.325589
# 4    -0.925657     -0.606245     -0.130608        1.368893          1.901418
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)    ...     \
# 0  0.132963  0.760800    0.131755      0.745985          0.739536    ...
# 1  0.453892  1.276809    0.452684      1.681731          1.768464    ...
# 2  0.720770  1.585687    0.721813      1.202693          1.027636    ...
# 3  0.578885  1.284076    0.577677      1.340396          1.207698    ...
# 4  1.095750  2.047187    1.096793      1.836448          1.552389    ...
#
# ...

# %%
# splitting data into training and test set for independent attributes
from sklearn.model_selection import train_test_split

# Split X and y into training and test set in 70:30 ratio
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.3,random_state=0)
Xtrain=np.array(xtrain)
Ytrain=np.array(ytrain)
Xtest=np.array(xtest)
Ytest=np.array(ytest)
Ytest=np.array(ytest)
Xtrain.shape
Ytrain.shape
Xtest.shape
Ytest.shape
# Out:
# (136, 22)
# (136, 1)
# (59, 22)
# (59, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

model = DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
 max_features=None, max_leaf_nodes=None,
 min_impurity_split=1e-07, min_samples_leaf=1,
 min_samples_split=2, min_weight_fraction_leaf=0.0,
 presort=False, random_state=None, splitter='best')


model.fit(Xtrain,Ytrain)
# Out:
# C:\Users\rajan\Anaconda3\lib\site-packages\sklearn\tree\tree.py:283: DeprecationWarning: The min_impurity_split parameter is deprecated. Its default value will change from 1e-7 to 0 in version 0.23, and it will be removed in 0.25. Use the min_impurity_decrease parameter instead.
#   DeprecationWarning)
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
Ypred=model.predict(Xtest)
acc=metrics.accuracy_score(Ytest,Ypred)
print(acc)
# Out:
# 0.8983050847457628

# %%
cm=metrics.confusion_matrix(Ytest,Ypred)
print(cm)
# Out:
# [[13  0]
#  [ 6 40]]

# %%
cr=metrics.classification_report(Ytest,Ypred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81        13
#            1       1.00      0.87      0.93        46
#
#    micro avg       0.90      0.90      0.90        59
#    macro avg       0.84      0.93      0.87        59
# weighted avg       0.93      0.90      0.90        59

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(Ytest, Ypred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9347826086956521

# %%
max_depths = np.linspace(1, 32, 32, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
    
   model_maxdepth = DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=max_depth,
     max_features=None, max_leaf_nodes=None,
     min_impurity_split=1e-07, min_samples_leaf=1,
                     
     min_samples_split=2, min_weight_fraction_leaf=0.0,
     presort=False, random_state=None, splitter='best')

   model_maxdepth.fit(Xtrain, Ytrain)
   train_pred = model_maxdepth.predict(Xtrain)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(Ytrain, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous train results
   train_results.append(roc_auc)
   Ypred_maxdepth = model_maxdepth.predict(Xtest)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(Ytest, Ypred_maxdepth)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous test results
   test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, 'b', label="Train AUC")
line2, = plt.plot(max_depths, test_results, 'r', label="Test AUC")
# Out:
# C:\Users\rajan\Anaconda3\lib\site-packages\sklearn\tree\tree.py:283: DeprecationWarning: The min_impurity_split parameter is deprecated. Its default value will change from 1e-7 to 0 in version 0.23, and it will be removed in 0.25. Use the min_impurity_decrease parameter instead.
#   DeprecationWarning)
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1.0,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# C:\Users\rajan\Anaconda3\lib\site-packages\sklearn\tree\tree.py:283: DeprecationWarning: The min_impurity_split parameter is deprecated. Its default value will change from 1e-7 to 0 in version 0.23, and it will be removed in 0.25. Use the min_impurity_decrease parameter instead.
#   DeprecationWarning)
# ...

# %%
#beyond depth =5 the model tends to give the similar level of accuracy.

# %%
min_samples_splits = np.linspace(0.1, 1.0, 10, endpoint=True)
train_results = []
test_results = []
for min_samples_split in min_samples_splits:
    model_minsample = DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
    max_features=None, max_leaf_nodes=None,
    min_impurity_split=1e-07, min_samples_leaf=1,          
    min_samples_split=min_samples_split, min_weight_fraction_leaf=0.0,
    presort=False, random_state=None, splitter='best')
      
    model_minsample.fit(Xtrain, Ytrain)
    train_pred = model_minsample.predict(Xtrain)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(Ytrain, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous train results
    train_results.append(roc_auc)
    Ypred_minsample = model_minsample.predict(Xtest)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(Ytest, Ypred_minsample)
    roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous test results
    test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(min_samples_splits, train_results, 'b', label="Train AUC")
line2, = plt.plot(min_samples_splits, test_results, 'r', label="Test AUC")
# Out:
# C:\Users\rajan\Anaconda3\lib\site-packages\sklearn\tree\tree.py:283: DeprecationWarning: The min_impurity_split parameter is deprecated. Its default value will change from 1e-7 to 0 in version 0.23, and it will be removed in 0.25. Use the min_impurity_decrease parameter instead.
#   DeprecationWarning)
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=0.1,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# C:\Users\rajan\Anaconda3\lib\site-packages\sklearn\tree\tree.py:283: DeprecationWarning: The min_impurity_split parameter is deprecated. Its default value will change from 1e-7 to 0 in version 0.23, and it will be removed in 0.25. Use the min_impurity_decrease parameter instead.
#   DeprecationWarning)
# ...

# %%
#when the minimum samle split is greater than 30% of the values the model tends to perform poor
# Regularization helps to better optimize the model parameters

# %% [markdown]
# ## Question 14-  Apply the Random forest model and print the accuracy of Random forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
Rf_model = RandomForestClassifier(n_estimators=50,criterion='entropy',max_depth=3,random_state=0 )
Rf_model.fit(Xtrain,Ytrain)

ypred_Rf=Rf_model.predict(Xtest)
acc=metrics.accuracy_score(Ytest,ypred_Rf)
print(acc)

cm=metrics.confusion_matrix(Ytest,ypred_Rf)
print(cm)
cr=metrics.classification_report(Ytest,ypred_Rf)
print(cr)
# Out:
# C:\Users\rajan\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)
# 0.9322033898305084
# [[ 9  4]
#  [ 0 46]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.82        13
#            1       0.92      1.00      0.96        46
#
#    micro avg       0.93      0.93      0.93        59
#    macro avg       0.96      0.85      0.89        59
# ...

# %%
max_depths = np.linspace(1, 32, 32, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
    
    from sklearn.ensemble import RandomForestClassifier
    Rf_model_maxdepth = RandomForestClassifier(n_estimators=50,criterion='entropy',max_depth=max_depth,random_state=0 )
    Rf_model_maxdepth.fit(Xtrain,Ytrain)

    train_pred = Rf_model_maxdepth.predict(Xtrain)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(Ytrain, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    # Add auc score to previous train results
    train_results.append(roc_auc)
    
    Ypred_maxdepth = Rf_model_maxdepth.predict(Xtest)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(Ytest, Ypred_maxdepth)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    # Add auc score to previous test results
    test_results.append(roc_auc)
    
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, 'b', label="Train AUC")
line2, = plt.plot(max_depths, test_results, 'r', label="Test AUC")
# Out:
# C:\Users\rajan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=1.0, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)
# C:\Users\rajan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
# ...

# %%
# Random forest gives the better result compared to simple DT which can be further optimized by regualrizing model parameters
#to achieve better accuracy

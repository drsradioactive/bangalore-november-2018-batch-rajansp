# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the input file and check the data dimension

# %%
credit_df=pd.read_csv("german_credit.csv")

# %%
credit_df.shape
credit_df.head()
credit_df.tail()
credit_df.shape
credit_df.dtypes
credit_df.info
credit_df.isnull().values.any()
credit_df.isnull().sum().sum()
credit_df.isna().values.any()
credit_df.isna().sum().sum()
credit_df.describe()
credit_df.describe().transpose()
# Out:
# (1000, 21)
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# 3              radio/television           7882                 ... < 100 DM
# 4                     car (new)           4870                 ... < 100 DM
#
#     present_emp_since  installment_as_income_perc  \
# 0       .. >= 7 years                           4
# 1  1 <= ... < 4 years                           2
# 2  4 <= ... < 7 years                           2
# 3  4 <= ... < 7 years                           2
# 4  1 <= ... < 4 years                           3
#
#                    personal_status_sex      ...       present_res_since  \
# 0                        male : single      ...                       4
# 1  female : divorced/separated/married      ...                       2
# 2                        male : single      ...                       3
# 3                        male : single      ...                       4
# 4                        male : single      ...                       4
#
#                                             property age  \
# 0                                        real estate  67
# 1                                        real estate  22
# 2                                        real estate  49
# 3  if not A121 : building society savings agreeme...  45
# 4                              unknown / no property  53
#
#    other_installment_plans   housing credits_this_bank  \
# 0                     none       own                 2
# 1                     none       own                 1
# 2                     none       own                 1
# 3                     none  for free                 1
# 4                     none  for free                 2
#
#                            job people_under_maintenance  \
# 0  skilled employee / official                        1
# 1  skilled employee / official                        1
# 2         unskilled - resident                        2
# 3  skilled employee / official                        2
# 4  skilled employee / official                        2
#
#                                    telephone foreign_worker
# 0  yes, registered under the customers name             yes
# 1                                       none            yes
# 2                                       none            yes
# 3                                       none            yes
# 4                                       none            yes
#
# [5 rows x 21 columns]
#      default account_check_status  duration_in_month  \
# 995        0  no checking account                 12
# 996        0               < 0 DM                 30
# 997        0  no checking account                 12
# 998        1               < 0 DM                 45
# 999        0    0 <= ... < 200 DM                 45
#
#                                         credit_history              purpose  \
# 995           existing credits paid back duly till now     radio/television
# 996           existing credits paid back duly till now           car (used)
# 997           existing credits paid back duly till now  domestic appliances
# 998           existing credits paid back duly till now  domestic appliances
# 999  critical account/ other credits existing (not ...           car (used)
#
#      credit_amount              savings   present_emp_since  \
# 995           1736         ... < 100 DM  4 <= ... < 7 years
# 996           3857         ... < 100 DM  1 <= ... < 4 years
# 997            804         ... < 100 DM       .. >= 7 years
# 998           1845         ... < 100 DM  1 <= ... < 4 years
# 999           4576  100 <= ... < 500 DM          unemployed
#
#      installment_as_income_perc                  personal_status_sex  \
# 995                           3  female : divorced/separated/married
# 996                           4            male : divorced/separated
# 997                           4                        male : single
# 998                           4                        male : single
# 999                           3                        male : single
#
#          ...       present_res_since  \
# 995      ...                       4
# 996      ...                       4
# 997      ...                       4
# 998      ...                       4
# 999      ...                       4
#
#                                               property age  \
# 995                                        real estate  31
# 996  if not A121 : building society savings agreeme...  40
# 997  if not A121/A122 : car or other, not in attrib...  38
# 998                              unknown / no property  23
# 999  if not A121/A122 : car or other, not in attrib...  27
#
#      other_installment_plans   housing credits_this_bank  \
# 995                     none       own                 1
# 996                     none       own                 1
# 997                     none       own                 1
# 998                     none  for free                 1
# 999                     none       own                 1
#
#                                                    job  \
# 995                               unskilled - resident
# 996  management/ self-employed/ highly qualified em...
# 997                        skilled employee / official
# 998                        skilled employee / official
# 999                        skilled employee / official
#
#     people_under_maintenance                                  telephone  \
# 995                        1                                       none
# 996                        1  yes, registered under the customers name
# 997                        1                                       none
# 998                        1  yes, registered under the customers name
# 999                        1                                       none
#
#     foreign_worker
# 995            yes
# 996            yes
# 997            yes
# 998            yes
# 999            yes
#
# [5 rows x 21 columns]
# (1000, 21)
# default                        int64
# account_check_status          object
# duration_in_month              int64
# credit_history                object
# purpose                       object
# credit_amount                  int64
# savings                       object
# present_emp_since             object
# installment_as_income_perc     int64
# personal_status_sex           object
# other_debtors                 object
# present_res_since              int64
# property                      object
# age                            int64
# other_installment_plans       object
# housing                       object
# credits_this_bank              int64
# job                           object
# people_under_maintenance       int64
# telephone                     object
# foreign_worker                object
# dtype: object
# <bound method DataFrame.info of      default                               account_check_status  \
# 0          0                                             < 0 DM
# 1          1                                  0 <= ... < 200 DM
# 2          0                                no checking account
# 3          0                                             < 0 DM
# 4          1                                             < 0 DM
# 5          0                                no checking account
# 6          0                                no checking account
# 7          0                                  0 <= ... < 200 DM
# 8          0                                no checking account
# 9          1                                  0 <= ... < 200 DM
# 10         1                                  0 <= ... < 200 DM
# 11         1                                             < 0 DM
# 12         0                                  0 <= ... < 200 DM
# 13         1                                             < 0 DM
# 14         0                                             < 0 DM
# 15         1                                             < 0 DM
# 16         0                                no checking account
# 17         0                                             < 0 DM
# 18         1                                  0 <= ... < 200 DM
# 19         0                                no checking account
# 20         0                                no checking account
# 21         0                                             < 0 DM
# 22         0                                             < 0 DM
# 23         0                                  0 <= ... < 200 DM
# 24         0                                no checking account
# 25         0                                             < 0 DM
# 26         0                                no checking account
# 27         0  >= 200 DM / salary assignments for at least 1 ...
# 28         0                                  0 <= ... < 200 DM
# 29         1                                             < 0 DM
# ..       ...                                                ...
# 970        0                                  0 <= ... < 200 DM
# 971        0                                no checking account
# 972        1                                             < 0 DM
# 973        1                                             < 0 DM
# 974        0                                no checking account
# 975        0  >= 200 DM / salary assignments for at least 1 ...
# 976        0                                  0 <= ... < 200 DM
# 977        0                                  0 <= ... < 200 DM
# 978        1                                no checking account
# 979        1                                  0 <= ... < 200 DM
# 980        1                                  0 <= ... < 200 DM
# 981        1                                no checking account
# 982        0  >= 200 DM / salary assignments for at least 1 ...
# 983        1                                             < 0 DM
# 984        0                                no checking account
# 985        0                                             < 0 DM
# 986        0  >= 200 DM / salary assignments for at least 1 ...
# 987        0                                no checking account
# 988        0                                             < 0 DM
# 989        0                                  0 <= ... < 200 DM
# 990        0                                no checking account
# 991        0                                no checking account
# 992        0                                             < 0 DM
# 993        0                                             < 0 DM
# 994        0                                no checking account
# 995        0                                no checking account
# 996        0                                             < 0 DM
# 997        0                                no checking account
# 998        1                                             < 0 DM
# 999        0                                  0 <= ... < 200 DM
#
#      duration_in_month                                     credit_history  \
# 0                    6  critical account/ other credits existing (not ...
# 1                   48           existing credits paid back duly till now
# 2                   12  critical account/ other credits existing (not ...
# 3                   42           existing credits paid back duly till now
# 4                   24                    delay in paying off in the past
# 5                   36           existing credits paid back duly till now
# 6                   24           existing credits paid back duly till now
# 7                   36           existing credits paid back duly till now
# 8                   12           existing credits paid back duly till now
# 9                   30  critical account/ other credits existing (not ...
# 10                  12           existing credits paid back duly till now
# 11                  48           existing credits paid back duly till now
# 12                  12           existing credits paid back duly till now
# 13                  24  critical account/ other credits existing (not ...
# 14                  15           existing credits paid back duly till now
# 15                  24           existing credits paid back duly till now
# 16                  24  critical account/ other credits existing (not ...
# 17                  30       no credits taken/ all credits paid back duly
# 18                  24           existing credits paid back duly till now
# 19                  24           existing credits paid back duly till now
# 20                   9  critical account/ other credits existing (not ...
# 21                   6           existing credits paid back duly till now
# 22                  10  critical account/ other credits existing (not ...
# 23                  12  critical account/ other credits existing (not ...
# 24                  10  critical account/ other credits existing (not ...
# 25                   6           existing credits paid back duly till now
# 26                   6       no credits taken/ all credits paid back duly
# 27                  12            all credits at this bank paid back duly
# 28                   7           existing credits paid back duly till now
# 29                  60                    delay in paying off in the past
# ..                 ...                                                ...
# 970                 15           existing credits paid back duly till now
# 971                 24           existing credits paid back duly till now
# 972                 24            all credits at this bank paid back duly
# 973                 60           existing credits paid back duly till now
# 974                 30  critical account/ other credits existing (not ...
# 975                 24           existing credits paid back duly till now
# 976                  6           existing credits paid back duly till now
# 977                 18                    delay in paying off in the past
# 978                 24                    delay in paying off in the past
# 979                 15            all credits at this bank paid back duly
# 980                 30  critical account/ other credits existing (not ...
# 981                 48           existing credits paid back duly till now
# 982                 21           existing credits paid back duly till now
# 983                 36           existing credits paid back duly till now
# 984                 24  critical account/ other credits existing (not ...
# 985                 15  critical account/ other credits existing (not ...
# 986                 42       no credits taken/ all credits paid back duly
# 987                 13           existing credits paid back duly till now
# 988                 24           existing credits paid back duly till now
# 989                 24  critical account/ other credits existing (not ...
# 990                 12  critical account/ other credits existing (not ...
# 991                 15            all credits at this bank paid back duly
# 992                 18           existing credits paid back duly till now
# 993                 36           existing credits paid back duly till now
# 994                 12           existing credits paid back duly till now
# 995                 12           existing credits paid back duly till now
# 996                 30           existing credits paid back duly till now
# 997                 12           existing credits paid back duly till now
# 998                 45           existing credits paid back duly till now
# 999                 45  critical account/ other credits existing (not ...
#
#                           purpose  credit_amount                      savings  \
# 0             domestic appliances           1169  unknown/ no savings account
# 1             domestic appliances           5951                 ... < 100 DM
# 2    (vacation - does not exist?)           2096                 ... < 100 DM
# 3                radio/television           7882                 ... < 100 DM
# 4                       car (new)           4870                 ... < 100 DM
# 5    (vacation - does not exist?)           9055  unknown/ no savings account
# 6                radio/television           2835        500 <= ... < 1000 DM
# 7                      car (used)           6948                 ... < 100 DM
# 8             domestic appliances           3059               .. >= 1000 DM
# 9                       car (new)           5234                 ... < 100 DM
# 10                      car (new)           1295                 ... < 100 DM
# 11                       business           4308                 ... < 100 DM
# 12            domestic appliances           1567                 ... < 100 DM
# 13                      car (new)           1199                 ... < 100 DM
# 14                      car (new)           1403                 ... < 100 DM
# 15            domestic appliances           1282          100 <= ... < 500 DM
# 16            domestic appliances           2424  unknown/ no savings account
# 17                       business           8072  unknown/ no savings account
# 18                     car (used)          12579                 ... < 100 DM
# 19            domestic appliances           3430        500 <= ... < 1000 DM
# 20                      car (new)           2134                 ... < 100 DM
# 21            domestic appliances           2647        500 <= ... < 1000 DM
# 22                      car (new)           2241                 ... < 100 DM
# 23                     car (used)           1804          100 <= ... < 500 DM
# 24               radio/television           2069  unknown/ no savings account
# 25               radio/television           1374                 ... < 100 DM
# 26            domestic appliances            426                 ... < 100 DM
# 27            domestic appliances            409               .. >= 1000 DM
# 28            domestic appliances           2415                 ... < 100 DM
# 29                       business           6836                 ... < 100 DM
# ..                            ...            ...                          ...
# 970                     education           1514          100 <= ... < 500 DM
# 971                     car (new)           7393                 ... < 100 DM
# 972                     car (new)           1193                 ... < 100 DM
# 973                      business           7297                 ... < 100 DM
# 974           domestic appliances           2831                 ... < 100 DM
# 975           domestic appliances           1258        500 <= ... < 1000 DM
# 976           domestic appliances            753                 ... < 100 DM
# 977                      business           2427  unknown/ no savings account
# 978                     car (new)           2538                 ... < 100 DM
# 979                     car (new)           1264          100 <= ... < 500 DM
# 980              radio/television           8386                 ... < 100 DM
# 981                      business           4844                 ... < 100 DM
# 982                     car (new)           2923          100 <= ... < 500 DM
# 983                    car (used)           8229                 ... < 100 DM
# 984              radio/television           2028                 ... < 100 DM
# 985              radio/television           1433                 ... < 100 DM
# 986                      business           6289                 ... < 100 DM
# 987           domestic appliances           1409          100 <= ... < 500 DM
# 988                    car (used)           6579                 ... < 100 DM
# 989           domestic appliances           1743                 ... < 100 DM
# 990  (vacation - does not exist?)           3565  unknown/ no savings account
# 991           domestic appliances           1569          100 <= ... < 500 DM
# 992           domestic appliances           1936  unknown/ no savings account
# 993              radio/television           3959                 ... < 100 DM
# 994                     car (new)           2390  unknown/ no savings account
# 995              radio/television           1736                 ... < 100 DM
# 996                    car (used)           3857                 ... < 100 DM
# 997           domestic appliances            804                 ... < 100 DM
# 998           domestic appliances           1845                 ... < 100 DM
# 999                    car (used)           4576          100 <= ... < 500 DM
#
#       present_emp_since  installment_as_income_perc  \
# 0         .. >= 7 years                           4
# 1    1 <= ... < 4 years                           2
# 2    4 <= ... < 7 years                           2
# 3    4 <= ... < 7 years                           2
# 4    1 <= ... < 4 years                           3
# 5    1 <= ... < 4 years                           2
# 6         .. >= 7 years                           3
# 7    1 <= ... < 4 years                           2
# 8    4 <= ... < 7 years                           2
# 9            unemployed                           4
# 10        ... < 1 year                            3
# 11        ... < 1 year                            3
# 12   1 <= ... < 4 years                           1
# 13        .. >= 7 years                           4
# 14   1 <= ... < 4 years                           2
# 15   1 <= ... < 4 years                           4
# 16        .. >= 7 years                           4
# 17        ... < 1 year                            2
# 18        .. >= 7 years                           4
# 19        .. >= 7 years                           3
# 20   1 <= ... < 4 years                           4
# 21   1 <= ... < 4 years                           2
# 22        ... < 1 year                            1
# 23        ... < 1 year                            3
# 24   1 <= ... < 4 years                           2
# 25   1 <= ... < 4 years                           1
# 26        .. >= 7 years                           4
# 27   1 <= ... < 4 years                           3
# 28   1 <= ... < 4 years                           3
# 29        .. >= 7 years                           3
# ..                  ...                         ...
# 970  1 <= ... < 4 years                           4
# 971  1 <= ... < 4 years                           1
# 972          unemployed                           1
# 973       .. >= 7 years                           4
# 974  1 <= ... < 4 years                           4
# 975  1 <= ... < 4 years                           3
# 976  1 <= ... < 4 years                           2
# 977       .. >= 7 years                           4
# 978       .. >= 7 years                           4
# 979  1 <= ... < 4 years                           2
# 980  4 <= ... < 7 years                           2
# 981          unemployed                           3
# 982  1 <= ... < 4 years                           1
# 983  1 <= ... < 4 years                           2
# 984  4 <= ... < 7 years                           2
# 985  1 <= ... < 4 years                           4
# 986       ... < 1 year                            2
# 987          unemployed                           2
# 988          unemployed                           4
# 989       .. >= 7 years                           4
# 990       ... < 1 year                            2
# 991       .. >= 7 years                           4
# 992  4 <= ... < 7 years                           2
# 993          unemployed                           4
# 994       .. >= 7 years                           4
# 995  4 <= ... < 7 years                           3
# 996  1 <= ... < 4 years                           4
# 997       .. >= 7 years                           4
# 998  1 <= ... < 4 years                           4
# 999          unemployed                           3
#
#                      personal_status_sex      ...       present_res_since  \
# 0                          male : single      ...                       4
# 1    female : divorced/separated/married      ...                       2
# 2                          male : single      ...                       3
# 3                          male : single      ...                       4
# 4                          male : single      ...                       4
# 5                          male : single      ...                       4
# 6                          male : single      ...                       4
# 7                          male : single      ...                       2
# 8              male : divorced/separated      ...                       4
# 9                 male : married/widowed      ...                       2
# 10   female : divorced/separated/married      ...                       1
# 11   female : divorced/separated/married      ...                       4
# 12   female : divorced/separated/married      ...                       1
# 13                         male : single      ...                       4
# 14   female : divorced/separated/married      ...                       4
# 15   female : divorced/separated/married      ...                       2
# 16                         male : single      ...                       4
# 17                         male : single      ...                       3
# 18   female : divorced/separated/married      ...                       2
# 19                         male : single      ...                       2
# 20                         male : single      ...                       4
# 21                         male : single      ...                       3
# 22                         male : single      ...                       3
# 23                         male : single      ...                       4
# 24                male : married/widowed      ...                       1
# 25                         male : single      ...                       2
# 26                male : married/widowed      ...                       4
# 27   female : divorced/separated/married      ...                       3
# 28                         male : single      ...                       2
# 29                         male : single      ...                       4
# ..                                   ...      ...                     ...
# 970                        male : single      ...                       2
# 971                        male : single      ...                       4
# 972  female : divorced/separated/married      ...                       4
# 973                        male : single      ...                       4
# 974  female : divorced/separated/married      ...                       2
# 975  female : divorced/separated/married      ...                       3
# 976  female : divorced/separated/married      ...                       3
# 977                        male : single      ...                       2
# 978                        male : single      ...                       4
# 979               male : married/widowed      ...                       2
# 980                        male : single      ...                       2
# 981                        male : single      ...                       2
# 982  female : divorced/separated/married      ...                       1
# 983                        male : single      ...                       2
# 984                        male : single      ...                       2
# 985  female : divorced/separated/married      ...                       3
# 986            male : divorced/separated      ...                       1
# 987  female : divorced/separated/married      ...                       4
# 988                        male : single      ...                       2
# 989                        male : single      ...                       2
# 990                        male : single      ...                       1
# 991                        male : single      ...                       4
# 992               male : married/widowed      ...                       4
# 993                        male : single      ...                       3
# 994                        male : single      ...                       3
# 995  female : divorced/separated/married      ...                       4
# 996            male : divorced/separated      ...                       4
# 997                        male : single      ...                       4
# 998                        male : single      ...                       4
# 999                        male : single      ...                       4
#
#                                               property age  \
# 0                                          real estate  67
# 1                                          real estate  22
# 2                                          real estate  49
# 3    if not A121 : building society savings agreeme...  45
# 4                                unknown / no property  53
# 5                                unknown / no property  35
# 6    if not A121 : building society savings agreeme...  53
# 7    if not A121/A122 : car or other, not in attrib...  35
# 8                                          real estate  61
# 9    if not A121/A122 : car or other, not in attrib...  28
# 10   if not A121/A122 : car or other, not in attrib...  25
# 11   if not A121 : building society savings agreeme...  24
# 12   if not A121/A122 : car or other, not in attrib...  22
# 13   if not A121/A122 : car or other, not in attrib...  60
# 14   if not A121/A122 : car or other, not in attrib...  28
# 15   if not A121/A122 : car or other, not in attrib...  32
# 16   if not A121 : building society savings agreeme...  53
# 17   if not A121/A122 : car or other, not in attrib...  25
# 18                               unknown / no property  44
# 19   if not A121/A122 : car or other, not in attrib...  31
# 20   if not A121/A122 : car or other, not in attrib...  48
# 21                                         real estate  44
# 22                                         real estate  48
# 23   if not A121 : building society savings agreeme...  44
# 24   if not A121/A122 : car or other, not in attrib...  26
# 25                                         real estate  36
# 26   if not A121/A122 : car or other, not in attrib...  39
# 27                                         real estate  42
# 28                                         real estate  34
# 29                               unknown / no property  63
# ..                                                 ...  ..
# 970                                        real estate  22
# 971  if not A121 : building society savings agreeme...  43
# 972                              unknown / no property  29
# 973                              unknown / no property  36
# 974  if not A121/A122 : car or other, not in attrib...  33
# 975  if not A121/A122 : car or other, not in attrib...  57
# 976                                        real estate  64
# 977  if not A121 : building society savings agreeme...  42
# 978  if not A121/A122 : car or other, not in attrib...  47
# 979  if not A121 : building society savings agreeme...  25
# 980  if not A121 : building society savings agreeme...  49
# 981  if not A121/A122 : car or other, not in attrib...  33
# 982  if not A121/A122 : car or other, not in attrib...  28
# 983  if not A121 : building society savings agreeme...  26
# 984  if not A121 : building society savings agreeme...  30
# 985  if not A121 : building society savings agreeme...  25
# 986  if not A121 : building society savings agreeme...  33
# 987                                        real estate  64
# 988                              unknown / no property  29
# 989  if not A121 : building society savings agreeme...  48
# 990  if not A121 : building society savings agreeme...  37
# 991  if not A121/A122 : car or other, not in attrib...  34
# 992  if not A121/A122 : car or other, not in attrib...  23
# 993  if not A121 : building society savings agreeme...  30
# 994  if not A121/A122 : car or other, not in attrib...  50
# 995                                        real estate  31
# 996  if not A121 : building society savings agreeme...  40
# 997  if not A121/A122 : car or other, not in attrib...  38
# 998                              unknown / no property  23
# 999  if not A121/A122 : car or other, not in attrib...  27
#
#      other_installment_plans   housing credits_this_bank  \
# 0                       none       own                 2
# 1                       none       own                 1
# 2                       none       own                 1
# 3                       none  for free                 1
# 4                       none  for free                 2
# 5                       none  for free                 1
# 6                       none       own                 1
# 7                       none      rent                 1
# 8                       none       own                 1
# 9                       none       own                 2
# 10                      none      rent                 1
# 11                      none      rent                 1
# 12                      none       own                 1
# 13                      none       own                 2
# 14                      none      rent                 1
# 15                      none       own                 1
# 16                      none       own                 2
# 17                      bank       own                 3
# 18                      none  for free                 1
# 19                      none       own                 1
# 20                      none       own                 3
# 21                      none      rent                 1
# 22                      none      rent                 2
# 23                      none       own                 1
# 24                      none       own                 2
# 25                      bank       own                 1
# 26                      none       own                 1
# 27                      none      rent                 2
# 28                      none       own                 1
# 29                      none       own                 2
# ..                       ...       ...               ...
# 970                     none       own                 1
# 971                     none       own                 1
# 972                     none      rent                 2
# 973                     none      rent                 1
# 974                     none       own                 1
# 975                     none       own                 1
# 976                     none       own                 1
# 977                     none       own                 2
# 978                     none       own                 2
# 979                     none      rent                 1
# 980                     none       own                 1
# 981                     bank      rent                 1
# 982                     bank       own                 1
# 983                     none       own                 1
# 984                     none       own                 2
# 985                     none      rent                 2
# 986                     none       own                 2
# 987                     none       own                 1
# 988                     none  for free                 1
# 989                     none       own                 2
# 990                     none       own                 2
# 991                     bank       own                 1
# 992                     none      rent                 2
# 993                     none       own                 1
# 994                     none       own                 1
# 995                     none       own                 1
# 996                     none       own                 1
# 997                     none       own                 1
# 998                     none  for free                 1
# 999                     none       own                 1
#
#                                                    job  \
# 0                          skilled employee / official
# 1                          skilled employee / official
# 2                                 unskilled - resident
# 3                          skilled employee / official
# 4                          skilled employee / official
# 5                                 unskilled - resident
# 6                          skilled employee / official
# 7    management/ self-employed/ highly qualified em...
# 8                                 unskilled - resident
# 9    management/ self-employed/ highly qualified em...
# 10                         skilled employee / official
# 11                         skilled employee / official
# 12                         skilled employee / official
# 13                                unskilled - resident
# 14                         skilled employee / official
# 15                                unskilled - resident
# 16                         skilled employee / official
# 17                         skilled employee / official
# 18   management/ self-employed/ highly qualified em...
# 19                         skilled employee / official
# 20                         skilled employee / official
# 21                         skilled employee / official
# 22                                unskilled - resident
# 23                         skilled employee / official
# 24                         skilled employee / official
# 25                                unskilled - resident
# 26                                unskilled - resident
# 27                         skilled employee / official
# 28                         skilled employee / official
# 29                         skilled employee / official
# ..                                                 ...
# 970                        skilled employee / official
# 971                               unskilled - resident
# 972               unemployed/ unskilled - non-resident
# 973                        skilled employee / official
# 974                        skilled employee / official
# 975                               unskilled - resident
# 976                        skilled employee / official
# 977                        skilled employee / official
# 978                               unskilled - resident
# 979                        skilled employee / official
# 980                        skilled employee / official
# 981  management/ self-employed/ highly qualified em...
# 982  management/ self-employed/ highly qualified em...
# 983                        skilled employee / official
# 984                               unskilled - resident
# 985                        skilled employee / official
# 986                        skilled employee / official
# 987                        skilled employee / official
# 988  management/ self-employed/ highly qualified em...
# 989                               unskilled - resident
# 990                               unskilled - resident
# 991                               unskilled - resident
# 992                               unskilled - resident
# 993  management/ self-employed/ highly qualified em...
# 994                        skilled employee / official
# 995                               unskilled - resident
# 996  management/ self-employed/ highly qualified em...
# 997                        skilled employee / official
# 998                        skilled employee / official
# 999                        skilled employee / official
#
#     people_under_maintenance                                  telephone  \
# 0                          1  yes, registered under the customers name
# 1                          1                                       none
# 2                          2                                       none
# 3                          2                                       none
# 4                          2                                       none
# 5                          2  yes, registered under the customers name
# 6                          1                                       none
# 7                          1  yes, registered under the customers name
# 8                          1                                       none
# 9                          1                                       none
# 10                         1                                       none
# 11                         1                                       none
# 12                         1  yes, registered under the customers name
# 13                         1                                       none
# 14                         1                                       none
# 15                         1                                       none
# 16                         1                                       none
# 17                         1                                       none
# 18                         1  yes, registered under the customers name
# 19                         2  yes, registered under the customers name
# 20                         1  yes, registered under the customers name
# 21                         2                                       none
# 22                         2                                       none
# 23                         1                                       none
# 24                         1                                       none
# 25                         1  yes, registered under the customers name
# 26                         1                                       none
# 27                         1                                       none
# 28                         1                                       none
# 29                         1  yes, registered under the customers name
# ..                       ...                                        ...
# 970                        1                                       none
# 971                        2                                       none
# 972                        1                                       none
# 973                        1                                       none
# 974                        1  yes, registered under the customers name
# 975                        1                                       none
# 976                        1                                       none
# 977                        1                                       none
# 978                        2                                       none
# 979                        1                                       none
# 980                        1                                       none
# 981                        1  yes, registered under the customers name
# 982                        1  yes, registered under the customers name
# 983                        2                                       none
# 984                        1                                       none
# 985                        1                                       none
# 986                        1                                       none
# 987                        1                                       none
# 988                        1  yes, registered under the customers name
# 989                        1                                       none
# 990                        2                                       none
# 991                        2                                       none
# 992                        1                                       none
# 993                        1  yes, registered under the customers name
# 994                        1  yes, registered under the customers name
# 995                        1                                       none
# 996                        1  yes, registered under the customers name
# 997                        1                                       none
# 998                        1  yes, registered under the customers name
# 999                        1                                       none
#
#     foreign_worker
# 0              yes
# 1              yes
# 2              yes
# 3              yes
# 4              yes
# 5              yes
# 6              yes
# 7              yes
# 8              yes
# 9              yes
# 10             yes
# 11             yes
# 12             yes
# 13             yes
# 14             yes
# 15             yes
# 16             yes
# 17             yes
# 18             yes
# 19             yes
# 20             yes
# 21             yes
# 22              no
# 23             yes
# 24              no
# 25             yes
# 26             yes
# 27             yes
# 28             yes
# 29             yes
# ..             ...
# 970            yes
# 971            yes
# 972            yes
# 973            yes
# 974            yes
# 975            yes
# 976            yes
# 977            yes
# 978            yes
# 979            yes
# 980            yes
# 981            yes
# 982            yes
# 983            yes
# 984            yes
# 985            yes
# 986            yes
# 987            yes
# 988            yes
# 989            yes
# 990            yes
# 991            yes
# 992            yes
# 993            yes
# 994            yes
# 995            yes
# 996            yes
# 997            yes
# 998            yes
# 999            yes
#
# [1000 rows x 21 columns]>
# False
# 0
# False
# 0
#            default  duration_in_month  credit_amount  \
# count  1000.000000        1000.000000    1000.000000
# mean      0.300000          20.903000    3271.258000
# std       0.458487          12.058814    2822.736876
# min       0.000000           4.000000     250.000000
# 25%       0.000000          12.000000    1365.500000
# 50%       0.000000          18.000000    2319.500000
# 75%       1.000000          24.000000    3972.250000
# max       1.000000          72.000000   18424.000000
#
#        installment_as_income_perc  present_res_since          age  \
# count                 1000.000000        1000.000000  1000.000000
# mean                     2.973000           2.845000    35.546000
# std                      1.118715           1.103718    11.375469
# min                      1.000000           1.000000    19.000000
# 25%                      2.000000           2.000000    27.000000
# 50%                      3.000000           3.000000    33.000000
# 75%                      4.000000           4.000000    42.000000
# max                      4.000000           4.000000    75.000000
#
#        credits_this_bank  people_under_maintenance
# count        1000.000000               1000.000000
# mean            1.407000                  1.155000
# std             0.577654                  0.362086
# min             1.000000                  1.000000
# 25%             1.000000                  1.000000
# 50%             1.000000                  1.000000
# 75%             2.000000                  1.000000
# max             4.000000                  2.000000
#                              count      mean          std    min     25%  \
# default                     1000.0     0.300     0.458487    0.0     0.0
# duration_in_month           1000.0    20.903    12.058814    4.0    12.0
# credit_amount               1000.0  3271.258  2822.736876  250.0  1365.5
# installment_as_income_perc  1000.0     2.973     1.118715    1.0     2.0
# present_res_since           1000.0     2.845     1.103718    1.0     2.0
# age                         1000.0    35.546    11.375469   19.0    27.0
# credits_this_bank           1000.0     1.407     0.577654    1.0     1.0
# people_under_maintenance    1000.0     1.155     0.362086    1.0     1.0
#
#                                50%      75%      max
# default                        0.0     1.00      1.0
# duration_in_month             18.0    24.00     72.0
# credit_amount               2319.5  3972.25  18424.0
# installment_as_income_perc     3.0     4.00      4.0
# present_res_since              3.0     4.00      4.0
# age                           33.0    42.00     75.0
# credits_this_bank              1.0     2.00      4.0
# people_under_maintenance       1.0     1.00      2.0

# %% [markdown]
# ### Q1 Randomly select 50% data for this use case( 1 Marks)
# ###### Hint: Use train_test_split

# %%
X =  credit_df.drop("default", axis=1)
Y =  credit_df.pop("default")

X.shape
X.head()
Y.shape
Y.head()
# Out:
# (1000, 20)
#   account_check_status  duration_in_month  \
# 0               < 0 DM                  6
# 1    0 <= ... < 200 DM                 48
# 2  no checking account                 12
# 3               < 0 DM                 42
# 4               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# 3              radio/television           7882                 ... < 100 DM
# 4                     car (new)           4870                 ... < 100 DM
#
#     present_emp_since  installment_as_income_perc  \
# 0       .. >= 7 years                           4
# 1  1 <= ... < 4 years                           2
# 2  4 <= ... < 7 years                           2
# 3  4 <= ... < 7 years                           2
# 4  1 <= ... < 4 years                           3
#
#                    personal_status_sex other_debtors  present_res_since  \
# 0                        male : single          none                  4
# 1  female : divorced/separated/married          none                  2
# 2                        male : single          none                  3
# 3                        male : single     guarantor                  4
# 4                        male : single          none                  4
#
#                                             property  age  \
# 0                                        real estate   67
# 1                                        real estate   22
# 2                                        real estate   49
# 3  if not A121 : building society savings agreeme...   45
# 4                              unknown / no property   53
#
#   other_installment_plans   housing  credits_this_bank  \
# 0                    none       own                  2
# 1                    none       own                  1
# 2                    none       own                  1
# 3                    none  for free                  1
# 4                    none  for free                  2
#
#                            job  people_under_maintenance  \
# 0  skilled employee / official                         1
# 1  skilled employee / official                         1
# 2         unskilled - resident                         2
# 3  skilled employee / official                         2
# 4  skilled employee / official                         2
#
#                                    telephone foreign_worker
# 0  yes, registered under the customers name             yes
# 1                                       none            yes
# 2                                       none            yes
# 3                                       none            yes
# 4                                       none            yes
# (1000,)
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: default, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X1, X2, Y1, Y2 = train_test_split(X, Y, test_size=0.50, random_state=1)

# %% [markdown]
# ### Q2.Prepare the model data by converting non-numeric to dummy ( 1 Marks)
# ##### Hint: Use get_dummies

# %%
# Print Shape of model data
X1=pd.get_dummies(X1)

# %%
X1.shape
X1.head()
X1.tail()
X1.shape
X1.dtypes
X1.info
X1.isnull().values.any()
X1.isnull().sum().sum()
X1.isna().values.any()
X1.isna().sum().sum()
X1.describe()
X1.describe().transpose()
# Out:
# (500, 61)
#      duration_in_month  credit_amount  installment_as_income_perc  \
# 789                 40           5998                           4
# 179                 21            571                           4
# 27                  12            409                           3
# 33                  12           1264                           4
# 334                 24           4110                           3
#
#      present_res_since  age  credits_this_bank  people_under_maintenance  \
# 789                  3   27                  1                         1
# 179                  4   65                  2                         1
# 27                   3   42                  2                         1
# 33                   4   57                  1                         1
# 334                  4   23                  2                         2
#
#      account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# 789                                       0                            1
# 179                                       0                            1
# 27                                        0                            0
# 33                                        0                            0
# 334                                       0                            1
#
#      account_check_status_>= 200 DM / salary assignments for at least 1 year  \
# 789                                                  0
# 179                                                  0
# 27                                                   1
# 33                                                   0
# 334                                                  0
#
#             ...          housing_own  housing_rent  \
# 789         ...                    1             0
# 179         ...                    1             0
# 27          ...                    0             1
# 33          ...                    0             1
# 334         ...                    0             1
#
#      job_management/ self-employed/ highly qualified employee/ officer  \
# 789                                                  0
# 179                                                  0
# 27                                                   0
# 33                                                   0
# 334                                                  0
#
#      job_skilled employee / official  \
# 789                                1
# 179                                1
# 27                                 1
# 33                                 0
# 334                                1
#
#      job_unemployed/ unskilled - non-resident  job_unskilled - resident  \
# 789                                         0                         0
# 179                                         0                         0
# 27                                          0                         0
# 33                                          0                         1
# 334                                         0                         0
#
#      telephone_none  telephone_yes, registered under the customers name   \
# 789               0                                                  1
# 179               1                                                  0
# 27                1                                                  0
# 33                1                                                  0
# 334               1                                                  0
#
#      foreign_worker_no  foreign_worker_yes
# 789                  0                   1
# 179                  0                   1
# 27                   0                   1
# 33                   0                   1
# 334                  0                   1
#
# [5 rows x 61 columns]
#      duration_in_month  credit_amount  installment_as_income_perc  \
# 767                 10           2901                           1
# 72                   8           1164                           3
# 908                 15           3594                           1
# 235                 24           1823                           4
# 37                  18           2100                           4
#
#      present_res_since  age  credits_this_bank  people_under_maintenance  \
# 767                  4   31                  1                         1
# 72                   4   51                  2                         2
# 908                  2   46                  2                         1
# 235                  2   30                  1                         2
# 37                   2   37                  1                         1
#
#      account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# 767                                       0                            0
# 72                                        0                            1
# 908                                       0                            0
# 235                                       0                            1
# 37                                        0                            0
#
#      account_check_status_>= 200 DM / salary assignments for at least 1 year  \
# 767                                                  0
# 72                                                   0
# 908                                                  0
# 235                                                  0
# 37                                                   1
#
#             ...          housing_own  housing_rent  \
# 767         ...                    0             1
# 72          ...                    0             0
# 908         ...                    1             0
# 235         ...                    1             0
# 37          ...                    1             0
#
#      job_management/ self-employed/ highly qualified employee/ officer  \
# 767                                                  0
# 72                                                   1
# 908                                                  0
# 235                                                  1
# 37                                                   0
#
#      job_skilled employee / official  \
# 767                                1
# 72                                 0
# 908                                0
# 235                                0
# 37                                 1
#
#      job_unemployed/ unskilled - non-resident  job_unskilled - resident  \
# 767                                         0                         0
# 72                                          0                         0
# 908                                         0                         1
# 235                                         0                         0
# 37                                          0                         0
#
#      telephone_none  telephone_yes, registered under the customers name   \
# 767               1                                                  0
# 72                0                                                  1
# 908               1                                                  0
# 235               1                                                  0
# 37                1                                                  0
#
#      foreign_worker_no  foreign_worker_yes
# 767                  0                   1
# 72                   0                   1
# 908                  0                   1
# 235                  0                   1
# 37                   0                   1
#
# [5 rows x 61 columns]
# (500, 61)
# duration_in_month                                                             int64
# credit_amount                                                                 int64
# installment_as_income_perc                                                    int64
# present_res_since                                                             int64
# age                                                                           int64
# credits_this_bank                                                             int64
# people_under_maintenance                                                      int64
# account_check_status_0 <= ... < 200 DM                                        uint8
# account_check_status_< 0 DM                                                   uint8
# account_check_status_>= 200 DM / salary assignments for at least 1 year       uint8
# account_check_status_no checking account                                      uint8
# credit_history_all credits at this bank paid back duly                        uint8
# credit_history_critical account/ other credits existing (not at this bank)    uint8
# credit_history_delay in paying off in the past                                uint8
# credit_history_existing credits paid back duly till now                       uint8
# credit_history_no credits taken/ all credits paid back duly                   uint8
# purpose_(vacation - does not exist?)                                          uint8
# purpose_business                                                              uint8
# purpose_car (new)                                                             uint8
# purpose_car (used)                                                            uint8
# purpose_domestic appliances                                                   uint8
# purpose_education                                                             uint8
# purpose_furniture/equipment                                                   uint8
# purpose_radio/television                                                      uint8
# purpose_repairs                                                               uint8
# purpose_retraining                                                            uint8
# savings_.. >= 1000 DM                                                         uint8
# savings_... < 100 DM                                                          uint8
# savings_100 <= ... < 500 DM                                                   uint8
# savings_500 <= ... < 1000 DM                                                  uint8
#                                                                               ...
# present_emp_since_.. >= 7 years                                               uint8
# present_emp_since_... < 1 year                                                uint8
# present_emp_since_1 <= ... < 4 years                                          uint8
# present_emp_since_4 <= ... < 7 years                                          uint8
# present_emp_since_unemployed                                                  uint8
# personal_status_sex_female : divorced/separated/married                       uint8
# personal_status_sex_male : divorced/separated                                 uint8
# personal_status_sex_male : married/widowed                                    uint8
# personal_status_sex_male : single                                             uint8
# other_debtors_co-applicant                                                    uint8
# other_debtors_guarantor                                                       uint8
# other_debtors_none                                                            uint8
# property_if not A121 : building society savings agreement/ life insurance     uint8
# property_if not A121/A122 : car or other, not in attribute 6                  uint8
# property_real estate                                                          uint8
# property_unknown / no property                                                uint8
# other_installment_plans_bank                                                  uint8
# other_installment_plans_none                                                  uint8
# other_installment_plans_stores                                                uint8
# housing_for free                                                              uint8
# housing_own                                                                   uint8
# housing_rent                                                                  uint8
# job_management/ self-employed/ highly qualified employee/ officer             uint8
# job_skilled employee / official                                               uint8
# job_unemployed/ unskilled - non-resident                                      uint8
# job_unskilled - resident                                                      uint8
# telephone_none                                                                uint8
# telephone_yes, registered under the customers name                            uint8
# foreign_worker_no                                                             uint8
# foreign_worker_yes                                                            uint8
# Length: 61, dtype: object
# <bound method DataFrame.info of      duration_in_month  credit_amount  installment_as_income_perc  \
# 789                 40           5998                           4
# 179                 21            571                           4
# 27                  12            409                           3
# 33                  12           1264                           4
# 334                 24           4110                           3
# 361                 12           3399                           2
# 293                 42           4796                           4
# 782                 12           1410                           2
# 959                 24           3069                           4
# 5                   36           9055                           2
# 197                 12            951                           4
# 790                 21           1188                           2
# 392                 36           3249                           2
# 543                 18           2864                           2
# 788                 48           6224                           4
# 631                 18           1553                           4
# 865                 15           2221                           2
# 510                 12            759                           4
# 122                 12           1768                           3
# 378                 36          14318                           4
# 38                  10           1225                           2
# 546                 24           2022                           4
# 523                 24           3488                           3
# 162                 15           1262                           4
# 67                  12           1007                           4
# 124                 18           1924                           4
# 4                   24           4870                           3
# 834                 15           2327                           2
# 759                 12            691                           4
# 427                 18           1149                           4
# ..                 ...            ...                         ...
# 398                 12           1223                           1
# 925                 12            697                           4
# 668                 12           4843                           3
# 490                 12           1934                           2
# 252                 30           2150                           4
# 907                 36           3711                           2
# 468                 33           2764                           2
# 914                 24           3161                           4
# 357                 36           4463                           4
# 254                  9           2030                           2
# 276                 18           2404                           2
# 178                 12           1963                           4
# 281                 12           1574                           4
# 390                 18           1820                           2
# 508                 24           1413                           4
# 749                 15           3029                           2
# 583                 36           2384                           4
# 972                 24           1193                           1
# 129                 12           3499                           3
# 144                 21           2288                           4
# 960                  6           1740                           2
# 847                 24           1249                           4
# 645                 36           7980                           4
# 715                 30           7596                           1
# 905                 12           1107                           2
# 767                 10           2901                           1
# 72                   8           1164                           3
# 908                 15           3594                           1
# 235                 24           1823                           4
# 37                  18           2100                           4
#
#      present_res_since  age  credits_this_bank  people_under_maintenance  \
# 789                  3   27                  1                         1
# 179                  4   65                  2                         1
# 27                   3   42                  2                         1
# 33                   4   57                  1                         1
# 334                  4   23                  2                         2
# 361                  3   37                  1                         1
# 293                  4   56                  1                         1
# 782                  2   31                  1                         1
# 959                  4   30                  1                         1
# 5                    4   35                  1                         2
# 197                  4   27                  4                         1
# 790                  4   39                  1                         2
# 392                  4   39                  1                         2
# 543                  1   34                  1                         2
# 788                  4   50                  1                         1
# 631                  3   44                  1                         1
# 865                  4   20                  1                         1
# 510                  2   26                  1                         1
# 122                  2   24                  1                         1
# 378                  2   57                  1                         1
# 38                   2   37                  1                         1
# 546                  4   37                  1                         1
# 523                  4   23                  1                         1
# 162                  3   36                  2                         1
# 67                   1   22                  1                         1
# 124                  3   27                  1                         1
# 4                    4   53                  2                         2
# 834                  3   25                  1                         1
# 759                  3   35                  2                         1
# 427                  3   46                  2                         1
# ..                 ...  ...                ...                       ...
# 398                  1   46                  2                         1
# 925                  2   46                  2                         1
# 668                  4   43                  2                         1
# 490                  2   26                  2                         1
# 252                  2   24                  1                         1
# 907                  2   27                  1                         1
# 468                  2   26                  2                         1
# 914                  2   31                  1                         1
# 357                  2   26                  2                         1
# 254                  1   24                  1                         1
# 276                  2   26                  2                         1
# 178                  2   31                  2                         2
# 281                  2   50                  1                         1
# 390                  2   30                  1                         1
# 508                  2   28                  1                         1
# 749                  2   33                  1                         1
# 583                  1   33                  1                         1
# 972                  4   29                  2                         1
# 129                  2   29                  2                         1
# 144                  4   23                  1                         1
# 960                  2   30                  2                         1
# 847                  2   28                  1                         1
# 645                  4   27                  2                         1
# 715                  4   63                  2                         1
# 905                  2   20                  1                         2
# 767                  4   31                  1                         1
# 72                   4   51                  2                         2
# 908                  2   46                  2                         1
# 235                  2   30                  1                         2
# 37                   2   37                  1                         1
#
#      account_check_status_0 <= ... < 200 DM  account_check_status_< 0 DM  \
# 789                                       0                            1
# 179                                       0                            1
# 27                                        0                            0
# 33                                        0                            0
# 334                                       0                            1
# 361                                       0                            0
# 293                                       0                            0
# 782                                       1                            0
# 959                                       1                            0
# 5                                         0                            0
# 197                                       1                            0
# 790                                       1                            0
# 392                                       0                            1
# 543                                       0                            0
# 788                                       1                            0
# 631                                       0                            1
# 865                                       0                            0
# 510                                       0                            1
# 122                                       0                            0
# 378                                       1                            0
# 38                                        0                            0
# 546                                       0                            0
# 523                                       0                            0
# 162                                       0                            0
# 67                                        1                            0
# 124                                       1                            0
# 4                                         0                            1
# 834                                       0                            0
# 759                                       0                            1
# 427                                       0                            0
# ..                                      ...                          ...
# 398                                       1                            0
# 925                                       0                            1
# 668                                       0                            1
# 490                                       0                            0
# 252                                       1                            0
# 907                                       1                            0
# 468                                       0                            0
# 914                                       0                            1
# 357                                       0                            0
# 254                                       1                            0
# 276                                       0                            0
# 178                                       0                            0
# 281                                       0                            0
# 390                                       0                            0
# 508                                       0                            0
# 749                                       0                            0
# 583                                       1                            0
# 972                                       0                            1
# 129                                       0                            1
# 144                                       0                            0
# 960                                       0                            0
# 847                                       0                            0
# 645                                       0                            0
# 715                                       0                            0
# 905                                       0                            1
# 767                                       0                            0
# 72                                        0                            1
# 908                                       0                            0
# 235                                       0                            1
# 37                                        0                            0
#
#      account_check_status_>= 200 DM / salary assignments for at least 1 year  \
# 789                                                  0
# 179                                                  0
# 27                                                   1
# 33                                                   0
# 334                                                  0
# 361                                                  1
# 293                                                  1
# 782                                                  0
# 959                                                  0
# 5                                                    0
# 197                                                  0
# 790                                                  0
# 392                                                  0
# 543                                                  1
# 788                                                  0
# 631                                                  0
# 865                                                  0
# 510                                                  0
# 122                                                  0
# 378                                                  0
# 38                                                   1
# 546                                                  0
# 523                                                  0
# 162                                                  0
# 67                                                   0
# 124                                                  0
# 4                                                    0
# 834                                                  1
# 759                                                  0
# 427                                                  0
# ..                                                 ...
# 398                                                  0
# 925                                                  0
# 668                                                  0
# 490                                                  0
# 252                                                  0
# 907                                                  0
# 468                                                  0
# 914                                                  0
# 357                                                  0
# 254                                                  0
# 276                                                  0
# 178                                                  0
# 281                                                  0
# 390                                                  0
# 508                                                  0
# 749                                                  0
# 583                                                  0
# 972                                                  0
# 129                                                  0
# 144                                                  0
# 960                                                  0
# 847                                                  0
# 645                                                  0
# 715                                                  0
# 905                                                  0
# 767                                                  0
# 72                                                   0
# 908                                                  0
# 235                                                  0
# 37                                                   1
#
#             ...          housing_own  housing_rent  \
# 789         ...                    1             0
# 179         ...                    1             0
# 27          ...                    0             1
# 33          ...                    0             1
# 334         ...                    0             1
# 361         ...                    1             0
# 293         ...                    0             0
# 782         ...                    1             0
# 959         ...                    0             0
# 5           ...                    0             0
# 197         ...                    0             1
# 790         ...                    1             0
# 392         ...                    0             0
# 543         ...                    1             0
# 788         ...                    0             0
# 631         ...                    1             0
# 865         ...                    0             1
# 510         ...                    1             0
# 122         ...                    0             1
# 378         ...                    0             0
# 38          ...                    1             0
# 546         ...                    1             0
# 523         ...                    1             0
# 162         ...                    1             0
# 67          ...                    1             0
# 124         ...                    0             1
# 4           ...                    0             0
# 834         ...                    1             0
# 759         ...                    1             0
# 427         ...                    1             0
# ..          ...                  ...           ...
# 398         ...                    0             1
# 925         ...                    1             0
# 668         ...                    0             1
# 490         ...                    1             0
# 252         ...                    1             0
# 907         ...                    1             0
# 468         ...                    1             0
# 914         ...                    0             1
# 357         ...                    1             0
# 254         ...                    1             0
# 276         ...                    1             0
# 178         ...                    0             1
# 281         ...                    1             0
# 390         ...                    1             0
# 508         ...                    1             0
# 749         ...                    1             0
# 583         ...                    0             1
# 972         ...                    0             1
# 129         ...                    1             0
# 144         ...                    1             0
# 960         ...                    0             1
# 847         ...                    1             0
# 645         ...                    0             1
# 715         ...                    1             0
# 905         ...                    0             1
# 767         ...                    0             1
# 72          ...                    0             0
# 908         ...                    1             0
# 235         ...                    1             0
# 37          ...                    1             0
#
#      job_management/ self-employed/ highly qualified employee/ officer  \
# 789                                                  0
# 179                                                  0
# 27                                                   0
# 33                                                   0
# 334                                                  0
# 361                                                  1
# 293                                                  0
# 782                                                  0
# 959                                                  0
# 5                                                    0
# 197                                                  0
# 790                                                  0
# 392                                                  1
# 543                                                  0
# 788                                                  0
# 631                                                  0
# 865                                                  0
# 510                                                  0
# 122                                                  0
# 378                                                  1
# 38                                                   0
# 546                                                  0
# 523                                                  0
# 162                                                  0
# 67                                                   0
# 124                                                  0
# 4                                                    0
# 834                                                  0
# 759                                                  0
# 427                                                  0
# ..                                                 ...
# 398                                                  0
# 925                                                  0
# 668                                                  0
# 490                                                  0
# 252                                                  0
# 907                                                  0
# 468                                                  0
# 914                                                  0
# 357                                                  1
# 254                                                  0
# 276                                                  0
# 178                                                  1
# 281                                                  0
# 390                                                  1
# 508                                                  0
# 749                                                  0
# 583                                                  0
# 972                                                  0
# 129                                                  0
# 144                                                  0
# 960                                                  0
# 847                                                  0
# 645                                                  0
# 715                                                  0
# 905                                                  1
# 767                                                  0
# 72                                                   1
# 908                                                  0
# 235                                                  1
# 37                                                   0
#
#      job_skilled employee / official  \
# 789                                1
# 179                                1
# 27                                 1
# 33                                 0
# 334                                1
# 361                                0
# 293                                1
# 782                                0
# 959                                1
# 5                                  0
# 197                                1
# 790                                1
# 392                                0
# 543                                0
# 788                                1
# 631                                1
# 865                                1
# 510                                1
# 122                                0
# 378                                0
# 38                                 1
# 546                                1
# 523                                1
# 162                                1
# 67                                 1
# 124                                1
# 4                                  1
# 834                                0
# 759                                1
# 427                                1
# ..                               ...
# 398                                1
# 925                                1
# 668                                1
# 490                                1
# 252                                1
# 907                                1
# 468                                1
# 914                                1
# 357                                0
# 254                                1
# 276                                1
# 178                                0
# 281                                1
# 390                                0
# 508                                1
# 749                                1
# 583                                0
# 972                                0
# 129                                1
# 144                                1
# 960                                1
# 847                                1
# 645                                1
# 715                                1
# 905                                0
# 767                                1
# 72                                 0
# 908                                0
# 235                                0
# 37                                 1
#
#      job_unemployed/ unskilled - non-resident  job_unskilled - resident  \
# 789                                         0                         0
# 179                                         0                         0
# 27                                          0                         0
# 33                                          0                         1
# 334                                         0                         0
# 361                                         0                         0
# 293                                         0                         0
# 782                                         0                         1
# 959                                         0                         0
# 5                                           0                         1
# 197                                         0                         0
# 790                                         0                         0
# 392                                         0                         0
# 543                                         0                         1
# 788                                         0                         0
# 631                                         0                         0
# 865                                         0                         0
# 510                                         0                         0
# 122                                         0                         1
# 378                                         0                         0
# 38                                          0                         0
# 546                                         0                         0
# 523                                         0                         0
# 162                                         0                         0
# 67                                          0                         0
# 124                                         0                         0
# 4                                           0                         0
# 834                                         0                         1
# 759                                         0                         0
# 427                                         0                         0
# ..                                        ...                       ...
# 398                                         0                         0
# 925                                         0                         0
# 668                                         0                         0
# 490                                         0                         0
# 252                                         0                         0
# 907                                         0                         0
# 468                                         0                         0
# 914                                         0                         0
# 357                                         0                         0
# 254                                         0                         0
# 276                                         0                         0
# 178                                         0                         0
# 281                                         0                         0
# 390                                         0                         0
# 508                                         0                         0
# 749                                         0                         0
# 583                                         0                         1
# 972                                         1                         0
# 129                                         0                         0
# 144                                         0                         0
# 960                                         0                         0
# 847                                         0                         0
# 645                                         0                         0
# 715                                         0                         0
# 905                                         0                         0
# 767                                         0                         0
# 72                                          0                         0
# 908                                         0                         1
# 235                                         0                         0
# 37                                          0                         0
#
#      telephone_none  telephone_yes, registered under the customers name   \
# 789               0                                                  1
# 179               1                                                  0
# 27                1                                                  0
# 33                1                                                  0
# 334               1                                                  0
# 361               1                                                  0
# 293               1                                                  0
# 782               0                                                  1
# 959               1                                                  0
# 5                 0                                                  1
# 197               1                                                  0
# 790               1                                                  0
# ...
# purpose_retraining                                  500.0     0.008
# savings_.. >= 1000 DM                               500.0     0.048
# savings_... < 100 DM                                500.0     0.604
# savings_100 <= ... < 500 DM                         500.0     0.108
# savings_500 <= ... < 1000 DM                        500.0     0.052
# ...                                                   ...       ...
# present_emp_since_.. >= 7 years                     500.0     0.222
# present_emp_since_... < 1 year                      500.0     0.150
# present_emp_since_1 <= ... < 4 years                500.0     0.380
# present_emp_since_4 <= ... < 7 years                500.0     0.184
# present_emp_since_unemployed                        500.0     0.064
# personal_status_sex_female : divorced/separated...  500.0     0.318
# personal_status_sex_male : divorced/separated       500.0     0.036
# personal_status_sex_male : married/widowed          500.0     0.094
# personal_status_sex_male : single                   500.0     0.552
# other_debtors_co-applicant                          500.0     0.050
# other_debtors_guarantor                             500.0     0.052
# other_debtors_none                                  500.0     0.898
# property_if not A121 : building society savings...  500.0     0.230
# property_if not A121/A122 : car or other, not i...  500.0     0.308
# property_real estate                                500.0     0.284
# property_unknown / no property                      500.0     0.178
# other_installment_plans_bank                        500.0     0.144
# other_installment_plans_none                        500.0     0.814
# other_installment_plans_stores                      500.0     0.042
# housing_for free                                    500.0     0.126
# housing_own                                         500.0     0.686
# housing_rent                                        500.0     0.188
# job_management/ self-employed/ highly qualified...  500.0     0.158
# job_skilled employee / official                     500.0     0.638
# job_unemployed/ unskilled - non-resident            500.0     0.014
# job_unskilled - resident                            500.0     0.190
# telephone_none                                      500.0     0.612
# telephone_yes, registered under the customers n...  500.0     0.388
# foreign_worker_no                                   500.0     0.040
# foreign_worker_yes                                  500.0     0.960
#
#                                                             std    min  \
# duration_in_month                                     11.850671    4.0
# credit_amount                                       2875.025473  343.0
# installment_as_income_perc                             1.125824    1.0
# present_res_since                                      1.076437    1.0
# age                                                   11.792266   19.0
# credits_this_bank                                      0.576771    1.0
# people_under_maintenance                               0.345245    1.0
# account_check_status_0 <= ... < 200 DM                 0.440163    0.0
# account_check_status_< 0 DM                            0.448462    0.0
# account_check_status_>= 200 DM / salary assignm...     0.258747    0.0
# account_check_status_no checking account               0.487783    0.0
# credit_history_all credits at this bank paid ba...     0.226244    0.0
# credit_history_critical account/ other credits ...     0.444404    0.0
# credit_history_delay in paying off in the past         0.302951    0.0
# credit_history_existing credits paid back duly ...     0.499202    0.0
# credit_history_no credits taken/ all credits pa...     0.191388    0.0
# purpose_(vacation - does not exist?)                   0.191388    0.0
# purpose_business                                       0.271565    0.0
# purpose_car (new)                                      0.440163    0.0
# purpose_car (used)                                     0.308146    0.0
# purpose_domestic appliances                            0.444404    0.0
# purpose_education                                      0.125601    0.0
# purpose_furniture/equipment                            0.125601    0.0
# purpose_radio/television                               0.392694    0.0
# purpose_repairs                                        0.117608    0.0
# purpose_retraining                                     0.089173    0.0
# savings_.. >= 1000 DM                                  0.213980    0.0
# savings_... < 100 DM                                   0.489554    0.0
# savings_100 <= ... < 500 DM                            0.310691    0.0
# savings_500 <= ... < 1000 DM                           0.222249    0.0
# ...                                                         ...    ...
# present_emp_since_.. >= 7 years                        0.416007    0.0
# present_emp_since_... < 1 year                         0.357429    0.0
# present_emp_since_1 <= ... < 4 years                   0.485873    0.0
# present_emp_since_4 <= ... < 7 years                   0.387872    0.0
# present_emp_since_unemployed                           0.244998    0.0
# personal_status_sex_female : divorced/separated...     0.466166    0.0
# personal_status_sex_male : divorced/separated          0.186477    0.0
# personal_status_sex_male : married/widowed             0.292121    0.0
# personal_status_sex_male : single                      0.497787    0.0
# other_debtors_co-applicant                             0.218163    0.0
# other_debtors_guarantor                                0.222249    0.0
# other_debtors_none                                     0.302951    0.0
# property_if not A121 : building society savings...     0.421254    0.0
# property_if not A121/A122 : car or other, not i...     0.462129    0.0
# property_real estate                                   0.451388    0.0
# property_unknown / no property                         0.382896    0.0
# other_installment_plans_bank                           0.351441    0.0
# other_installment_plans_none                           0.389496    0.0
# other_installment_plans_stores                         0.200790    0.0
# housing_for free                                       0.332182    0.0
# housing_own                                            0.464581    0.0
# housing_rent                                           0.391103    0.0
# job_management/ self-employed/ highly qualified...     0.365106    0.0
# job_skilled employee / official                        0.481060    0.0
# job_unemployed/ unskilled - non-resident               0.117608    0.0
# job_unskilled - resident                               0.392694    0.0
# telephone_none                                         0.487783    0.0
# telephone_yes, registered under the customers n...     0.487783    0.0
# foreign_worker_no                                      0.196155    0.0
# foreign_worker_yes                                     0.196155    0.0
#
#                                                         25%     50%      75%  \
# duration_in_month                                     12.00    18.0    24.00
# credit_amount                                       1369.25  2342.5  4070.25
# installment_as_income_perc                             2.00     3.0     4.00
# present_res_since                                      2.00     3.0     4.00
# age                                                   27.00    33.0    43.00
# credits_this_bank                                      1.00     1.0     2.00
# people_under_maintenance                               1.00     1.0     1.00
# account_check_status_0 <= ... < 200 DM                 0.00     0.0     1.00
# account_check_status_< 0 DM                            0.00     0.0     1.00
# account_check_status_>= 200 DM / salary assignm...     0.00     0.0     0.00
# account_check_status_no checking account               0.00     0.0     1.00
# credit_history_all credits at this bank paid ba...     0.00     0.0     0.00
# credit_history_critical account/ other credits ...     0.00     0.0     1.00
# credit_history_delay in paying off in the past         0.00     0.0     0.00
# credit_history_existing credits paid back duly ...     0.00     1.0     1.00
# credit_history_no credits taken/ all credits pa...     0.00     0.0     0.00
# purpose_(vacation - does not exist?)                   0.00     0.0     0.00
# purpose_business                                       0.00     0.0     0.00
# purpose_car (new)                                      0.00     0.0     1.00
# purpose_car (used)                                     0.00     0.0     0.00
# purpose_domestic appliances                            0.00     0.0     1.00
# purpose_education                                      0.00     0.0     0.00
# purpose_furniture/equipment                            0.00     0.0     0.00
# purpose_radio/television                               0.00     0.0     0.00
# purpose_repairs                                        0.00     0.0     0.00
# purpose_retraining                                     0.00     0.0     0.00
# savings_.. >= 1000 DM                                  0.00     0.0     0.00
# savings_... < 100 DM                                   0.00     1.0     1.00
# savings_100 <= ... < 500 DM                            0.00     0.0     0.00
# savings_500 <= ... < 1000 DM                           0.00     0.0     0.00
# ...                                                     ...     ...      ...
# present_emp_since_.. >= 7 years                        0.00     0.0     0.00
# present_emp_since_... < 1 year                         0.00     0.0     0.00
# present_emp_since_1 <= ... < 4 years                   0.00     0.0     1.00
# present_emp_since_4 <= ... < 7 years                   0.00     0.0     0.00
# present_emp_since_unemployed                           0.00     0.0     0.00
# personal_status_sex_female : divorced/separated...     0.00     0.0     1.00
# personal_status_sex_male : divorced/separated          0.00     0.0     0.00
# personal_status_sex_male : married/widowed             0.00     0.0     0.00
# personal_status_sex_male : single                      0.00     1.0     1.00
# other_debtors_co-applicant                             0.00     0.0     0.00
# other_debtors_guarantor                                0.00     0.0     0.00
# other_debtors_none                                     1.00     1.0     1.00
# property_if not A121 : building society savings...     0.00     0.0     0.00
# property_if not A121/A122 : car or other, not i...     0.00     0.0     1.00
# property_real estate                                   0.00     0.0     1.00
# property_unknown / no property                         0.00     0.0     0.00
# other_installment_plans_bank                           0.00     0.0     0.00
# other_installment_plans_none                           1.00     1.0     1.00
# other_installment_plans_stores                         0.00     0.0     0.00
# housing_for free                                       0.00     0.0     0.00
# housing_own                                            0.00     1.0     1.00
# housing_rent                                           0.00     0.0     0.00
# job_management/ self-employed/ highly qualified...     0.00     0.0     0.00
# job_skilled employee / official                        0.00     1.0     1.00
# job_unemployed/ unskilled - non-resident               0.00     0.0     0.00
# job_unskilled - resident                               0.00     0.0     0.00
# telephone_none                                         0.00     1.0     1.00
# telephone_yes, registered under the customers n...     0.00     0.0     1.00
# foreign_worker_no                                      0.00     0.0     0.00
# foreign_worker_yes                                     1.00     1.0     1.00
#
#                                                         max
# duration_in_month                                      60.0
# credit_amount                                       18424.0
# installment_as_income_perc                              4.0
# present_res_since                                       4.0
# age                                                    75.0
# credits_this_bank                                       4.0
# people_under_maintenance                                2.0
# account_check_status_0 <= ... < 200 DM                  1.0
# account_check_status_< 0 DM                             1.0
# account_check_status_>= 200 DM / salary assignm...      1.0
# account_check_status_no checking account                1.0
# credit_history_all credits at this bank paid ba...      1.0
# credit_history_critical account/ other credits ...      1.0
# credit_history_delay in paying off in the past          1.0
# credit_history_existing credits paid back duly ...      1.0
# credit_history_no credits taken/ all credits pa...      1.0
# purpose_(vacation - does not exist?)                    1.0
# purpose_business                                        1.0
# purpose_car (new)                                       1.0
# purpose_car (used)                                      1.0
# purpose_domestic appliances                             1.0
# purpose_education                                       1.0
# purpose_furniture/equipment                             1.0
# purpose_radio/television                                1.0
# purpose_repairs                                         1.0
# purpose_retraining                                      1.0
# savings_.. >= 1000 DM                                   1.0
# savings_... < 100 DM                                    1.0
# savings_100 <= ... < 500 DM                             1.0
# savings_500 <= ... < 1000 DM                            1.0
# ...                                                     ...
# present_emp_since_.. >= 7 years                         1.0
# present_emp_since_... < 1 year                          1.0
# present_emp_since_1 <= ... < 4 years                    1.0
# present_emp_since_4 <= ... < 7 years                    1.0
# present_emp_since_unemployed                            1.0
# personal_status_sex_female : divorced/separated...      1.0
# personal_status_sex_male : divorced/separated           1.0
# personal_status_sex_male : married/widowed              1.0
# personal_status_sex_male : single                       1.0
# other_debtors_co-applicant                              1.0
# other_debtors_guarantor                                 1.0
# other_debtors_none                                      1.0
# property_if not A121 : building society savings...      1.0
# property_if not A121/A122 : car or other, not i...      1.0
# property_real estate                                    1.0
# property_unknown / no property                          1.0
# other_installment_plans_bank                            1.0
# other_installment_plans_none                            1.0
# other_installment_plans_stores                          1.0
# housing_for free                                        1.0
# housing_own                                             1.0
# housing_rent                                            1.0
# job_management/ self-employed/ highly qualified...      1.0
# job_skilled employee / official                         1.0
# job_unemployed/ unskilled - non-resident                1.0
# job_unskilled - resident                                1.0
# telephone_none                                          1.0
# telephone_yes, registered under the customers n...      1.0
# foreign_worker_no                                       1.0
# foreign_worker_yes                                      1.0
#
# [61 rows x 8 columns]

# %% [markdown]
# ### Check for highly correlated variables but don't required any treatment for this use case

# %%
X1.corr()
# Out:
#                                                     duration_in_month  \
# duration_in_month                                            1.000000
# credit_amount                                                0.621934
# installment_as_income_perc                                   0.121678
# present_res_since                                           -0.009039
# age                                                         -0.054504
# credits_this_bank                                           -0.078458
# people_under_maintenance                                    -0.057544
# account_check_status_0 <= ... < 200 DM                       0.139030
# account_check_status_< 0 DM                                 -0.038817
# account_check_status_>= 200 DM / salary assignm...          -0.038696
# account_check_status_no checking account                    -0.069243
# credit_history_all credits at this bank paid ba...           0.070704
# credit_history_critical account/ other credits ...          -0.061656
# credit_history_delay in paying off in the past               0.152454
# credit_history_existing credits paid back duly ...          -0.109452
# credit_history_no credits taken/ all credits pa...           0.103747
# purpose_(vacation - does not exist?)                         0.086076
# purpose_business                                             0.145638
# purpose_car (new)                                           -0.143347
# purpose_car (used)                                           0.149909
# purpose_domestic appliances                                 -0.044913
# purpose_education                                            0.048706
# purpose_furniture/equipment                                  0.070248
# purpose_radio/television                                    -0.058096
# purpose_repairs                                             -0.032850
# purpose_retraining                                          -0.083273
# savings_.. >= 1000 DM                                       -0.036726
# savings_... < 100 DM                                        -0.043301
# savings_100 <= ... < 500 DM                                  0.039835
# savings_500 <= ... < 1000 DM                                -0.017826
# ...                                                               ...
# present_emp_since_.. >= 7 years                              0.031480
# present_emp_since_... < 1 year                              -0.069240
# present_emp_since_1 <= ... < 4 years                         0.000759
# present_emp_since_4 <= ... < 7 years                         0.020502
# present_emp_since_unemployed                                 0.013600
# personal_status_sex_female : divorced/separated...          -0.083254
# personal_status_sex_male : divorced/separated               -0.000548
# personal_status_sex_male : married/widowed                  -0.116337
# personal_status_sex_male : single                            0.146441
# other_debtors_co-applicant                                   0.022905
# other_debtors_guarantor                                     -0.057392
# other_debtors_none                                           0.025609
# property_if not A121 : building society savings...          -0.091715
# property_if not A121/A122 : car or other, not i...           0.143219
# property_real estate                                        -0.245338
# property_unknown / no property                               0.217272
# other_installment_plans_bank                                 0.014235
# other_installment_plans_none                                -0.049515
# other_installment_plans_stores                               0.071134
# housing_for free                                             0.194154
# housing_own                                                 -0.038749
# housing_rent                                                -0.118875
# job_management/ self-employed/ highly qualified...           0.196724
# job_skilled employee / official                              0.011255
# job_unemployed/ unskilled - non-resident                    -0.034287
# job_unskilled - resident                                    -0.186423
# telephone_none                                              -0.185221
# telephone_yes, registered under the customers n...           0.185221
# foreign_worker_no                                           -0.127211
# foreign_worker_yes                                           0.127211
#
#                                                     credit_amount  \
# duration_in_month                                        0.621934
# credit_amount                                            1.000000
# installment_as_income_perc                              -0.215371
# present_res_since                                        0.038010
# age                                                      0.058086
# credits_this_bank                                       -0.021106
# people_under_maintenance                                 0.019018
# account_check_status_0 <= ... < 200 DM                   0.138910
# account_check_status_< 0 DM                             -0.082235
# account_check_status_>= 200 DM / salary assignm...      -0.088007
# account_check_status_no checking account                -0.003059
# credit_history_all credits at this bank paid ba...      -0.012746
# credit_history_critical account/ other credits ...       0.003212
# credit_history_delay in paying off in the past           0.149106
# credit_history_existing credits paid back duly ...      -0.141036
# credit_history_no credits taken/ all credits pa...       0.139455
# purpose_(vacation - does not exist?)                     0.108451
# purpose_business                                         0.068353
# purpose_car (new)                                       -0.041129
# purpose_car (used)                                       0.274033
# purpose_domestic appliances                             -0.200087
# purpose_education                                       -0.000159
# purpose_furniture/equipment                              0.191737
# purpose_radio/television                                -0.062536
# purpose_repairs                                         -0.083850
# purpose_retraining                                      -0.071556
# savings_.. >= 1000 DM                                   -0.053370
# savings_... < 100 DM                                    -0.041113
# savings_100 <= ... < 500 DM                             -0.032013
# savings_500 <= ... < 1000 DM                            -0.060907
# ...                                                           ...
# present_emp_since_.. >= 7 years                          0.032094
# present_emp_since_... < 1 year                          -0.082717
# present_emp_since_1 <= ... < 4 years                     0.003567
# present_emp_since_4 <= ... < 7 years                     0.000449
# present_emp_since_unemployed                             0.058394
# personal_status_sex_female : divorced/separated...      -0.098285
# personal_status_sex_male : divorced/separated           -0.001216
# personal_status_sex_male : married/widowed              -0.166489
# personal_status_sex_male : single                        0.190200
# other_debtors_co-applicant                               0.047613
# other_debtors_guarantor                                 -0.087920
# other_debtors_none                                       0.030212
# property_if not A121 : building society savings...      -0.043650
# property_if not A121/A122 : car or other, not i...       0.086191
# property_real estate                                    -0.269928
# property_unknown / no property                           0.262210
# other_installment_plans_bank                             0.047435
# other_installment_plans_none                            -0.078692
# other_installment_plans_stores                           0.069622
# housing_for free                                         0.238881
# housing_own                                             -0.109663
# housing_rent                                            -0.072627
# job_management/ self-employed/ highly qualified...       0.375525
# job_skilled employee / official                         -0.125468
# job_unemployed/ unskilled - non-resident                -0.076678
# job_unskilled - resident                                -0.172477
# telephone_none                                          -0.318831
# telephone_yes, registered under the customers n...       0.318831
# foreign_worker_no                                       -0.062949
# foreign_worker_yes                                       0.062949
#
#                                                     installment_as_income_perc  \
# duration_in_month                                                     0.121678
# credit_amount                                                        -0.215371
# installment_as_income_perc                                            1.000000
# present_res_since                                                     0.028310
# age                                                                   0.042569
# credits_this_bank                                                     0.017900
# people_under_maintenance                                             -0.088701
# account_check_status_0 <= ... < 200 DM                               -0.032336
# account_check_status_< 0 DM                                           0.054283
# account_check_status_>= 200 DM / salary assignm...                   -0.041112
# account_check_status_no checking account                              0.001080
# credit_history_all credits at this bank paid ba...                    0.033580
# credit_history_critical account/ other credits ...                    0.025395
# credit_history_delay in paying off in the past                       -0.021834
# credit_history_existing credits paid back duly ...                    0.001826
# credit_history_no credits taken/ all credits pa...                   -0.068862
# purpose_(vacation - does not exist?)                                 -0.003757
# purpose_business                                                     -0.017305
# purpose_car (new)                                                    -0.044468
# purpose_car (used)                                                   -0.124474
# purpose_domestic appliances                                           0.197629
# purpose_education                                                     0.052040
# purpose_furniture/equipment                                          -0.047165
# purpose_radio/television                                             -0.081683
# purpose_repairs                                                       0.069441
# purpose_retraining                                                   -0.013254
# savings_.. >= 1000 DM                                                 0.041727
# savings_... < 100 DM                                                 -0.016842
# savings_100 <= ... < 500 DM                                           0.003071
# savings_500 <= ... < 1000 DM                                          0.009483
# ...                                                                        ...
# present_emp_since_.. >= 7 years                                       0.116916
# present_emp_since_... < 1 year                                       -0.018426
# present_emp_since_1 <= ... < 4 years                                 -0.095400
# present_emp_since_4 <= ... < 7 years                                  0.017109
# present_emp_since_unemployed                                         -0.009532
# personal_status_sex_female : divorced/separated...                   -0.097921
# personal_status_sex_male : divorced/separated                        -0.081023
# personal_status_sex_male : married/widowed                            0.011870
# personal_status_sex_male : single                                     0.115087
# other_debtors_co-applicant                                            0.017134
# other_debtors_guarantor                                               0.025501
# other_debtors_none                                                   -0.031047
# property_if not A121 : building society savings...                   -0.069046
# property_if not A121/A122 : car or other, not i...                    0.026716
# property_real estate                                                 -0.008171
# property_unknown / no property                                        0.053351
# other_installment_plans_bank                                         -0.025082
# other_installment_plans_none                                          0.023710
# other_installment_plans_stores                                       -0.002092
# housing_for free                                                      0.017641
# housing_own                                                           0.029932
# housing_rent                                                         -0.050538
# job_management/ self-employed/ highly qualified...                    0.037229
# job_skilled employee / official                                       0.021447
# job_unemployed/ unskilled - non-resident                             -0.066777
# job_unskilled - resident                                             -0.040887
# telephone_none                                                        0.009868
# telephone_yes, registered under the customers n...                   -0.009868
# foreign_worker_no                                                    -0.039202
# foreign_worker_yes                                                    0.039202
#
#                                                     present_res_since  \
# duration_in_month                                           -0.009039
# credit_amount                                                0.038010
# installment_as_income_perc                                   0.028310
# present_res_since                                            1.000000
# age                                                          0.273547
# credits_this_bank                                            0.064556
# people_under_maintenance                                     0.057483
# account_check_status_0 <= ... < 200 DM                      -0.057776
# account_check_status_< 0 DM                                  0.030969
# account_check_status_>= 200 DM / salary assignm...          -0.035688
# account_check_status_no checking account                     0.042594
# credit_history_all credits at this bank paid ba...           0.022876
# credit_history_critical account/ other credits ...           0.125258
# credit_history_delay in paying off in the past               0.007006
# credit_history_existing credits paid back duly ...          -0.121130
# credit_history_no credits taken/ all credits pa...          -0.013035
# purpose_(vacation - does not exist?)                         0.016147
# purpose_business                                            -0.009598
# purpose_car (new)                                            0.014127
# purpose_car (used)                                           0.111287
# purpose_domestic appliances                                 -0.092582
# purpose_education                                            0.031423
# purpose_furniture/equipment                                  0.031423
# purpose_radio/television                                    -0.012800
# purpose_repairs                                             -0.031976
# purpose_retraining                                           0.011691
# savings_.. >= 1000 DM                                       -0.014269
# savings_... < 100 DM                                        -0.132035
# savings_100 <= ... < 500 DM                                  0.051293
# savings_500 <= ... < 1000 DM                                 0.038868
# ...                                                               ...
# present_emp_since_.. >= 7 years                              0.261977
# present_emp_since_... < 1 year                              -0.153654
# present_emp_since_1 <= ... < 4 years                        -0.158631
# present_emp_since_4 <= ... < 7 years                        -0.038974
# present_emp_since_unemployed                                 0.155625
# personal_status_sex_female : divorced/separated...           0.025000
# personal_status_sex_male : divorced/separated               -0.004792
# personal_status_sex_male : married/widowed                  -0.111019
# personal_status_sex_male : single                            0.043533
# other_debtors_co-applicant                                   0.046934
# other_debtors_guarantor                                     -0.011392
# other_debtors_none                                          -0.025441
# property_if not A121 : building society savings...          -0.039333
# property_if not A121/A122 : car or other, not i...          -0.050115
# property_real estate                                        -0.091232
# property_unknown / no property                               0.211310
# other_installment_plans_bank                                 0.016316
# other_installment_plans_none                                 0.028583
# other_installment_plans_stores                              -0.084003
# housing_for free                                             0.228775
# housing_own                                                 -0.256385
# housing_rent                                                 0.110245
# job_management/ self-employed/ highly qualified...          -0.025189
# job_skilled employee / official                             -0.005186
# job_unemployed/ unskilled - non-resident                     0.047173
# job_unskilled - resident                                     0.015645
# telephone_none                                              -0.065494
# telephone_yes, registered under the customers n...           0.065494
# foreign_worker_no                                           -0.087317
# foreign_worker_yes                                           0.087317
#
#                                                          age  \
# duration_in_month                                  -0.054504
# credit_amount                                       0.058086
# installment_as_income_perc                          0.042569
# present_res_since                                   0.273547
# age                                                 1.000000
# credits_this_bank                                   0.142372
# people_under_maintenance                            0.097632
# account_check_status_0 <= ... < 200 DM             -0.077660
# account_check_status_< 0 DM                        -0.008085
# account_check_status_>= 200 DM / salary assignm...  0.051976
# account_check_status_no checking account            0.049941
# credit_history_all credits at this bank paid ba...  0.001016
# credit_history_critical account/ other credits ...  0.191111
# credit_history_delay in paying off in the past     -0.006296
# credit_history_existing credits paid back duly ... -0.145510
# credit_history_no credits taken/ all credits pa... -0.055458
# purpose_(vacation - does not exist?)                0.043993
# purpose_business                                    0.018799
# purpose_car (new)                                   0.084884
# purpose_car (used)                                  0.104635
# purpose_domestic appliances                        -0.075808
# purpose_education                                   0.060627
# purpose_furniture/equipment                         0.010565
# purpose_radio/television                           -0.140769
# purpose_repairs                                    -0.007468
# purpose_retraining                                 -0.024958
# savings_.. >= 1000 DM                               0.023368
# savings_... < 100 DM                               -0.061529
# savings_100 <= ... < 500 DM                        -0.089867
# savings_500 <= ... < 1000 DM                        0.075223
# ...                                                      ...
# present_emp_since_.. >= 7 years                     0.279149
# present_emp_since_... < 1 year                     -0.227174
# present_emp_since_1 <= ... < 4 years               -0.093584
# present_emp_since_4 <= ... < 7 years               -0.084652
# present_emp_since_unemployed                        0.177041
# personal_status_sex_female : divorced/separated... -0.144661
# personal_status_sex_male : divorced/separated       0.074336
# personal_status_sex_male : married/widowed         -0.173437
# personal_status_sex_male : single                   0.209404
# other_debtors_co-applicant                         -0.025394
# other_debtors_guarantor                            -0.016535
# other_debtors_none                                  0.030417
# property_if not A121 : building society savings... -0.037825
# property_if not A121/A122 : car or other, not i... -0.151029
# property_real estate                                0.013776
# property_unknown / no property                      0.207654
# other_installment_plans_bank                        0.015605
# other_installment_plans_none                       -0.011243
# other_installment_plans_stores                     -0.005505
# housing_for free                                    0.256559
# housing_own                                        -0.027520
# housing_rent                                       -0.185217
# job_management/ self-employed/ highly qualified...  0.131774
# job_skilled employee / official                    -0.194528
# job_unemployed/ unskilled - non-resident            0.115356
# job_unskilled - resident                            0.081238
# telephone_none                                     -0.144705
# telephone_yes, registered under the customers n...  0.144705
# foreign_worker_no                                  -0.027273
# foreign_worker_yes                                  0.027273
#
#                                                     credits_this_bank  \
# duration_in_month                                           -0.078458
# credit_amount                                               -0.021106
# installment_as_income_perc                                   0.017900
# present_res_since                                            0.064556
# age                                                          0.142372
# credits_this_bank                                            1.000000
# people_under_maintenance                                     0.114729
# account_check_status_0 <= ... < 200 DM                      -0.074201
# account_check_status_< 0 DM                                 -0.074377
# account_check_status_>= 200 DM / salary assignm...          -0.032228
# account_check_status_no checking account                     0.152434
# credit_history_all credits at this bank paid ba...          -0.073716
# credit_history_critical account/ other credits ...           0.500377
# credit_history_delay in paying off in the past               0.155977
# credit_history_existing credits paid back duly ...          -0.544285
# credit_history_no credits taken/ all credits pa...           0.098034
# purpose_(vacation - does not exist?)                        -0.029047
# purpose_business                                             0.051178
# purpose_car (new)                                            0.083674
# purpose_car (used)                                          -0.024806
# purpose_domestic appliances                                 -0.007818
# purpose_education                                           -0.005533
# purpose_furniture/equipment                                  0.049794
# purpose_radio/television                                    -0.079631
# purpose_repairs                                             -0.053178
# purpose_retraining                                          -0.023378
# savings_.. >= 1000 DM                                        0.022733
# savings_... < 100 DM                                        -0.026970
# savings_100 <= ... < 500 DM                                  0.038023
# savings_500 <= ... < 1000 DM                                 0.009380
# ...                                                               ...
# present_emp_since_.. >= 7 years                              0.105236
# present_emp_since_... < 1 year                              -0.097209
# present_emp_since_1 <= ... < 4 years                        -0.028604
# present_emp_since_4 <= ... < 7 years                         0.019707
# present_emp_since_unemployed                                -0.011345
# personal_status_sex_female : divorced/separated...          -0.108820
# personal_status_sex_male : divorced/separated                0.052171
# personal_status_sex_male : married/widowed                  -0.045198
# personal_status_sex_male : single                            0.108887
# other_debtors_co-applicant                                   0.047779
# other_debtors_guarantor                                     -0.006253
# other_debtors_none                                          -0.029819
# property_if not A121 : building society savings...          -0.008248
# property_if not A121/A122 : car or other, not i...           0.010526
# property_real estate                                         0.055421
# property_unknown / no property                              -0.068965
# other_installment_plans_bank                                 0.051410
# other_installment_plans_none                                -0.033898
# other_installment_plans_stores                              -0.024226
# housing_for free                                            -0.054391
# housing_own                                                  0.050856
# housing_rent                                                -0.014214
# job_management/ self-employed/ highly qualified...          -0.053292
# job_skilled employee / official                              0.002889
# job_unemployed/ unskilled - non-resident                     0.094538
# job_unskilled - resident                                     0.017696
# telephone_none                                               0.004274
# telephone_yes, registered under the customers n...          -0.004274
# foreign_worker_no                                           -0.017713
# foreign_worker_yes                                           0.017713
#
#                                                     people_under_maintenance  \
# duration_in_month                                                  -0.057544
# credit_amount                                                       0.019018
# installment_as_income_perc                                         -0.088701
# present_res_since                                                   0.057483
# age                                                                 0.097632
# credits_this_bank                                                   0.114729
# people_under_maintenance                                            1.000000
# account_check_status_0 <= ... < 200 DM                             -0.093340
# account_check_status_< 0 DM                                         0.101191
# account_check_status_>= 200 DM / salary assignm...                  0.000718
# account_check_status_no checking account                           -0.009187
# credit_history_all credits at this bank paid ba...                  0.083999
# credit_history_critical account/ other credits ...                  0.017894
# credit_history_delay in paying off in the past                      0.018432
# credit_history_existing credits paid back duly ...                 -0.081208
# credit_history_no credits taken/ all credits pa...                  0.041793
# purpose_(vacation - does not exist?)                               -0.018865
# purpose_business                                                   -0.032489
# purpose_car (new)                                                   0.144032
# purpose_car (used)                                                  0.031759
# purpose_domestic appliances                                        -0.060475
# purpose_education                                                  -0.004806
# purpose_furniture/equipment                                         0.041408
# purpose_radio/television                                           -0.075533
# purpose_repairs                                                    -0.047677
# purpose_retraining                                                 -0.035931
# savings_.. >= 1000 DM                                              -0.008464
# savings_... < 100 DM                                               -0.019872
# savings_100 <= ... < 500 DM                                        -0.027127
# savings_500 <= ... < 1000 DM                                        0.036878
# ...                                                                      ...
# present_emp_since_.. >= 7 years                                     0.037422
# present_emp_since_... < 1 year                                     -0.054403
# present_emp_since_1 <= ... < 4 years                                0.021265
# present_emp_since_4 <= ... < 7 years                                0.019515
# present_emp_since_unemployed                                       -0.057241
# personal_status_sex_female : divorced/separated...                 -0.210958
# personal_status_sex_male : divorced/separated                      -0.046194
# personal_status_sex_male : married/widowed                         -0.128880
# personal_status_sex_male : single                                   0.290494
# other_debtors_co-applicant                                         -0.065186
# other_debtors_guarantor                                             0.062995
# other_debtors_none                                                  0.000728
# property_if not A121 : building society savings...                 -0.067105
# property_if not A121/A122 : car or other, not i...                 -0.053407
# property_real estate                                                0.018055
# property_unknown / no property                                      0.117003
# other_installment_plans_bank                                        0.067123
# other_installment_plans_none                                       -0.091891
# other_installment_plans_stores                                      0.060766
# housing_for free                                                    0.145140
# housing_own                                                        -0.091633
# housing_rent                                                       -0.014426
# job_management/ self-employed/ highly qualified...                  0.001558
# job_skilled employee / official                                    -0.084729
# job_unemployed/ unskilled - non-resident                           -0.047677
# job_unskilled - resident                                            0.116626
# telephone_none                                                     -0.026513
# telephone_yes, registered under the customers n...                  0.026513
# foreign_worker_no                                                   0.007102
# foreign_worker_yes                                                 -0.007102
#
#                                                     account_check_status_0 <= ... < 200 DM  \
# duration_in_month                                                                 0.139030
# credit_amount                                                                     0.138910
# installment_as_income_perc                                                       -0.032336
# present_res_since                                                                -0.057776
# age                                                                              -0.077660
# credits_this_bank                                                                -0.074201
# people_under_maintenance                                                         -0.093340
# account_check_status_0 <= ... < 200 DM                                            1.000000
# account_check_status_< 0 DM                                                      -0.369723
# account_check_status_>= 200 DM / salary assignm...                               -0.165964
# account_check_status_no checking account                                         -0.474420
# credit_history_all credits at this bank paid ba...                               -0.001489
# credit_history_critical account/ other credits ...                               -0.157464
# credit_history_delay in paying off in the past                                    0.084730
# credit_history_existing credits paid back duly ...                                0.061872
# credit_history_no credits taken/ all credits pa...                                0.071890
# purpose_(vacation - does not exist?)                                             -0.023265
# purpose_business                                                                  0.109310
# purpose_car (new)                                                                -0.024018
# purpose_car (used)                                                               -0.057416
# purpose_domestic appliances                                                      -0.014036
# purpose_education                                                                 0.069018
# purpose_furniture/equipment                                                       0.105267
# purpose_radio/television                                                         -0.021913
# purpose_repairs                                                                  -0.070998
# purpose_retraining                                                                0.048606
# savings_.. >= 1000 DM                                                            -0.006128
# savings_... < 100 DM                                                             -0.066254
# savings_100 <= ... < 500 DM                                                       0.173679
# savings_500 <= ... < 1000 DM                                                     -0.037120
# ...                                                                                    ...
# present_emp_since_.. >= 7 years                                                  -0.033730
# present_emp_since_... < 1 year                                                    0.080885
# present_emp_since_1 <= ... < 4 years                                             -0.044791
# present_emp_since_4 <= ... < 7 years                                             -0.001221
# present_emp_since_unemployed                                                      0.030031
# personal_status_sex_female : divorced/separated...                                0.081473
# personal_status_sex_male : divorced/separated                                     0.031349
# personal_status_sex_male : married/widowed                                        0.041863
# personal_status_sex_male : single                                                -0.112609
# other_debtors_co-applicant                                                       -0.011478
# other_debtors_guarantor                                                           0.126764
# other_debtors_none                                                               -0.084730
# property_if not A121 : building society savings...                               -0.055445
# property_if not A121/A122 : car or other, not i...                                0.026127
# property_real estate                                                             -0.002058
# property_unknown / no property                                                    0.031891
# other_installment_plans_bank                                                      0.027672
# other_installment_plans_none                                                     -0.007411
# other_installment_plans_stores                                                   -0.034058
# housing_for free                                                                 -0.006935
# housing_own                                                                      -0.018287
# housing_rent                                                                      0.027613
# job_management/ self-employed/ highly qualified...                                0.091056
# job_skilled employee / official                                                  -0.062256
# job_unemployed/ unskilled - non-resident                                         -0.032286
# job_unskilled - resident                                                          0.001275
# telephone_none                                                                   -0.029607
# telephone_yes, registered under the customers n...                                0.029607
# foreign_worker_no                                                                -0.051992
# foreign_worker_yes                                                                0.051992
#
#                                                     account_check_status_< 0 DM  \
# duration_in_month                                                     -0.038817
# credit_amount                                                         -0.082235
# installment_as_income_perc                                             0.054283
# present_res_since                                                      0.030969
# age                                                                   -0.008085
# credits_this_bank                                                     -0.074377
# people_under_maintenance                                               0.101191
# account_check_status_0 <= ... < 200 DM                                -0.369723
# account_check_status_< 0 DM                                            1.000000
# account_check_status_>= 200 DM / salary assignm...                    -0.172841
# account_check_status_no checking account                              -0.494076
# credit_history_all credits at this bank paid ba...                     0.128265
# credit_history_critical account/ other credits ...                    -0.085772
# credit_history_delay in paying off in the past                        -0.105878
# credit_history_existing credits paid back duly ...                     0.076052
# credit_history_no credits taken/ all credits pa...                     0.016764
# purpose_(vacation - does not exist?)                                   0.040113
# purpose_business                                                      -0.117160
# purpose_car (new)                                                      0.066822
# purpose_car (used)                                                    -0.068651
# purpose_domestic appliances                                           -0.085772
# purpose_education                                                     -0.043547
# purpose_furniture/equipment                                           -0.007969
# purpose_radio/television                                               0.120508
# purpose_repairs                                                        0.116039
# purpose_retraining                                                    -0.005612
# savings_.. >= 1000 DM                                                 -0.076684
# savings_... < 100 DM                                                   0.292496
# savings_100 <= ... < 500 DM                                           -0.129618
# savings_500 <= ... < 1000 DM                                          -0.105116
# ...                                                                         ...
# present_emp_since_.. >= 7 years                                       -0.052183
# present_emp_since_... < 1 year                                         0.076888
# present_emp_since_1 <= ... < 4 years                                  -0.025936
# present_emp_since_4 <= ... < 7 years                                  -0.018157
# present_emp_since_unemployed                                           0.056615
# personal_status_sex_female : divorced/separated...                     0.036407
# personal_status_sex_male : divorced/separated                          0.023868
# personal_status_sex_male : married/widowed                            -0.046901
# personal_status_sex_male : single                                     -0.015512
# other_debtors_co-applicant                                             0.062473
# other_debtors_guarantor                                                0.015522
# other_debtors_none                                                    -0.056376
# property_if not A121 : building society savings...                     0.106397
# property_if not A121/A122 : car or other, not i...                    -0.085209
# property_real estate                                                  -0.054211
# property_unknown / no property                                         0.049693
# other_installment_plans_bank                                           0.050657
# other_installment_plans_none                                          -0.059039
# other_installment_plans_stores                                         0.025861
# housing_for free                                                       0.073800
# housing_own                                                           -0.109210
# housing_rent                                                           0.067046
# job_management/ self-employed/ highly qualified...                    -0.036253
# job_skilled employee / official                                        0.021532
# job_unemployed/ unskilled - non-resident                               0.002052
# job_unskilled - resident                                               0.006714
# telephone_none                                                         0.100149
# telephone_yes, registered under the customers n...                    -0.100149
# foreign_worker_no                                                      0.010024
# foreign_worker_yes                                                    -0.010024
#
#                                                     account_check_status_>= 200 DM / salary assignments for at least 1 year  \
# duration_in_month                                                                           -0.038696
# credit_amount                                                                               -0.088007
# installment_as_income_perc                                                                  -0.041112
# present_res_since                                                                           -0.035688
# age                                                                                          0.051976
# credits_this_bank                                                                           -0.032228
# people_under_maintenance                                                                     0.000718
# account_check_status_0 <= ... < 200 DM                                                      -0.165964
# account_check_status_< 0 DM                                                                 -0.172841
# account_check_status_>= 200 DM / salary assignm...                                           1.000000
# account_check_status_no checking account                                                    -0.221785
# credit_history_all credits at this bank paid ba...                                           0.001917
# credit_history_critical account/ other credits ...                                           0.004880
# credit_history_delay in paying off in the past                                              -0.017180
# credit_history_existing credits paid back duly ...                                           0.010922
# credit_history_no credits taken/ all credits pa...                                          -0.014892
# purpose_(vacation - does not exist?)                                                        -0.014892
# purpose_business                                                                             0.003422
# purpose_car (new)                                                                           -0.007601
# purpose_car (used)                                                                          -0.045644
# purpose_domestic appliances                                                                  0.057164
# purpose_education                                                                           -0.035519
# purpose_furniture/equipment                                                                 -0.035519
# purpose_radio/television                                                                     0.003156
# purpose_repairs                                                                              0.032664
# purpose_retraining                                                                          -0.025014
# savings_.. >= 1000 DM                                                                        0.046040
# savings_... < 100 DM                                                                         0.019871
# savings_100 <= ... < 500 DM                                                                 -0.047065
# savings_500 <= ... < 1000 DM                                                                 0.074158
# ...                                                                                               ...
# present_emp_since_.. >= 7 years                                                              0.018767
# present_emp_since_... < 1 year                                                               0.013001
# present_emp_since_1 <= ... < 4 years                                                         0.021041
# present_emp_since_4 <= ... < 7 years                                                        -0.032428
# present_emp_since_unemployed                                                                -0.041223
# personal_status_sex_female : divorced/separated...                                          -0.024058
# personal_status_sex_male : divorced/separated                                                0.112307
# personal_status_sex_male : married/widowed                                                  -0.010181
# ...
# telephone_none                                            1.000000
# telephone_yes, registered under the customers n...       -1.000000
# foreign_worker_no                                         0.099696
# foreign_worker_yes                                       -0.099696
#
#                                                     telephone_yes, registered under the customers name   \
# duration_in_month                                                                            0.185221
# credit_amount                                                                                0.318831
# installment_as_income_perc                                                                  -0.009868
# present_res_since                                                                            0.065494
# age                                                                                          0.144705
# credits_this_bank                                                                           -0.004274
# people_under_maintenance                                                                     0.026513
# account_check_status_0 <= ... < 200 DM                                                       0.029607
# account_check_status_< 0 DM                                                                 -0.100149
# account_check_status_>= 200 DM / salary assignm...                                          -0.063004
# account_check_status_no checking account                                                     0.098780
# credit_history_all credits at this bank paid ba...                                          -0.026803
# credit_history_critical account/ other credits ...                                           0.014976
# credit_history_delay in paying off in the past                                               0.097804
# credit_history_existing credits paid back duly ...                                          -0.049248
# credit_history_no credits taken/ all credits pa...                                          -0.029452
# purpose_(vacation - does not exist?)                                                         0.034947
# purpose_business                                                                             0.067776
# purpose_car (new)                                                                           -0.045064
# purpose_car (used)                                                                           0.125807
# purpose_domestic appliances                                                                 -0.086716
# purpose_education                                                                           -0.036112
# purpose_furniture/equipment                                                                  0.160148
# purpose_radio/television                                                                    -0.061308
# purpose_repairs                                                                              0.009921
# purpose_retraining                                                                           0.020640
# savings_.. >= 1000 DM                                                                       -0.025190
# savings_... < 100 DM                                                                        -0.026653
# savings_100 <= ... < 500 DM                                                                 -0.091929
# savings_500 <= ... < 1000 DM                                                                 0.035344
# ...                                                                                               ...
# present_emp_since_.. >= 7 years                                                              0.009204
# present_emp_since_... < 1 year                                                              -0.081610
# present_emp_since_1 <= ... < 4 years                                                        -0.006088
# present_emp_since_4 <= ... < 7 years                                                         0.013812
# present_emp_since_unemployed                                                                 0.093639
# personal_status_sex_female : divorced/separated...                                          -0.120670
# personal_status_sex_male : divorced/separated                                                0.022384
# personal_status_sex_male : married/widowed                                                  -0.045511
# personal_status_sex_male : single                                                            0.131327
# other_debtors_co-applicant                                                                   0.005650
# other_debtors_guarantor                                                                     -0.075569
# other_debtors_none                                                                           0.051370
# property_if not A121 : building society savings...                                           0.023212
# property_if not A121/A122 : car or other, not i...                                           0.046656
# property_real estate                                                                        -0.146501
# property_unknown / no property                                                               0.090860
# other_installment_plans_bank                                                                 0.024128
# other_installment_plans_none                                                                -0.020210
# other_installment_plans_stores                                                              -0.003028
# housing_for free                                                                             0.105820
# housing_own                                                                                  0.016944
# housing_rent                                                                                -0.110005
# job_management/ self-employed/ highly qualified...                                           0.431516
# job_skilled employee / official                                                             -0.126158
# job_unemployed/ unskilled - non-resident                                                    -0.059945
# job_unskilled - resident                                                                    -0.228702
# telephone_none                                                                              -1.000000
# telephone_yes, registered under the customers n...                                           1.000000
# foreign_worker_no                                                                           -0.099696
# foreign_worker_yes                                                                           0.099696
#
#                                                     foreign_worker_no  \
# duration_in_month                                           -0.127211
# credit_amount                                               -0.062949
# installment_as_income_perc                                  -0.039202
# present_res_since                                           -0.087317
# age                                                         -0.027273
# credits_this_bank                                           -0.017713
# people_under_maintenance                                     0.007102
# account_check_status_0 <= ... < 200 DM                      -0.051992
# account_check_status_< 0 DM                                  0.010024
# account_check_status_>= 200 DM / salary assignm...          -0.017373
# account_check_status_no checking account                     0.046916
# credit_history_all credits at this bank paid ba...          -0.048769
# credit_history_critical account/ other credits ...           0.036782
# credit_history_delay in paying off in the past              -0.068795
# credit_history_existing credits paid back duly ...           0.026196
# credit_history_no credits taken/ all credits pa...           0.012811
# purpose_(vacation - does not exist?)                        -0.040569
# purpose_business                                            -0.022572
# purpose_car (new)                                            0.110482
# purpose_car (used)                                          -0.037133
# purpose_domestic appliances                                 -0.055174
# purpose_education                                           -0.026029
# purpose_furniture/equipment                                  0.055312
# purpose_radio/television                                     0.005203
# purpose_repairs                                             -0.024323
# purpose_retraining                                          -0.018331
# savings_.. >= 1000 DM                                        0.097399
# savings_... < 100 DM                                        -0.001670
# savings_100 <= ... < 500 DM                                 -0.038144
# savings_500 <= ... < 1000 DM                                -0.001839
# ...                                                               ...
# present_emp_since_.. >= 7 years                             -0.059922
# present_emp_since_... < 1 year                               0.028583
# present_emp_since_1 <= ... < 4 years                         0.008411
# present_emp_since_4 <= ... < 7 years                         0.061108
# present_emp_since_unemployed                                -0.053376
# personal_status_sex_female : divorced/separated...          -0.051721
# personal_status_sex_male : divorced/separated               -0.039446
# personal_status_sex_male : married/widowed                   0.109117
# personal_status_sex_male : single                           -0.000821
# other_debtors_co-applicant                                   0.046829
# other_debtors_guarantor                                      0.044130
# other_debtors_none                                          -0.066097
# property_if not A121 : building society savings...           0.106711
# property_if not A121/A122 : car or other, not i...          -0.091966
# property_real estate                                         0.052509
# property_unknown / no property                              -0.068306
# other_installment_plans_bank                                -0.025582
# other_installment_plans_none                                 0.045115
# other_installment_plans_stores                              -0.042740
# housing_for free                                            -0.077504
# housing_own                                                  0.050139
# housing_rent                                                 0.006269
# job_management/ self-employed/ highly qualified...          -0.060441
# job_skilled employee / official                             -0.037378
# job_unemployed/ unskilled - non-resident                     0.062545
# job_unskilled - resident                                     0.083252
# telephone_none                                               0.099696
# telephone_yes, registered under the customers n...          -0.099696
# foreign_worker_no                                            1.000000
# foreign_worker_yes                                          -1.000000
#
#                                                     foreign_worker_yes
# duration_in_month                                             0.127211
# credit_amount                                                 0.062949
# installment_as_income_perc                                    0.039202
# present_res_since                                             0.087317
# age                                                           0.027273
# credits_this_bank                                             0.017713
# people_under_maintenance                                     -0.007102
# account_check_status_0 <= ... < 200 DM                        0.051992
# account_check_status_< 0 DM                                  -0.010024
# account_check_status_>= 200 DM / salary assignm...            0.017373
# account_check_status_no checking account                     -0.046916
# credit_history_all credits at this bank paid ba...            0.048769
# credit_history_critical account/ other credits ...           -0.036782
# credit_history_delay in paying off in the past                0.068795
# credit_history_existing credits paid back duly ...           -0.026196
# credit_history_no credits taken/ all credits pa...           -0.012811
# purpose_(vacation - does not exist?)                          0.040569
# purpose_business                                              0.022572
# purpose_car (new)                                            -0.110482
# purpose_car (used)                                            0.037133
# purpose_domestic appliances                                   0.055174
# purpose_education                                             0.026029
# purpose_furniture/equipment                                  -0.055312
# purpose_radio/television                                     -0.005203
# purpose_repairs                                               0.024323
# purpose_retraining                                            0.018331
# savings_.. >= 1000 DM                                        -0.097399
# savings_... < 100 DM                                          0.001670
# savings_100 <= ... < 500 DM                                   0.038144
# savings_500 <= ... < 1000 DM                                  0.001839
# ...                                                                ...
# present_emp_since_.. >= 7 years                               0.059922
# present_emp_since_... < 1 year                               -0.028583
# present_emp_since_1 <= ... < 4 years                         -0.008411
# present_emp_since_4 <= ... < 7 years                         -0.061108
# present_emp_since_unemployed                                  0.053376
# personal_status_sex_female : divorced/separated...            0.051721
# personal_status_sex_male : divorced/separated                 0.039446
# personal_status_sex_male : married/widowed                   -0.109117
# personal_status_sex_male : single                             0.000821
# other_debtors_co-applicant                                   -0.046829
# other_debtors_guarantor                                      -0.044130
# other_debtors_none                                            0.066097
# property_if not A121 : building society savings...           -0.106711
# property_if not A121/A122 : car or other, not i...            0.091966
# property_real estate                                         -0.052509
# property_unknown / no property                                0.068306
# other_installment_plans_bank                                  0.025582
# other_installment_plans_none                                 -0.045115
# other_installment_plans_stores                                0.042740
# housing_for free                                              0.077504
# housing_own                                                  -0.050139
# housing_rent                                                 -0.006269
# job_management/ self-employed/ highly qualified...            0.060441
# job_skilled employee / official                               0.037378
# job_unemployed/ unskilled - non-resident                     -0.062545
# job_unskilled - resident                                     -0.083252
# telephone_none                                               -0.099696
# telephone_yes, registered under the customers n...            0.099696
# foreign_worker_no                                            -1.000000
# foreign_worker_yes                                            1.000000
#
# [61 rows x 61 columns]

# %% [markdown]
# ### Drop the original variables which are converted to dummy

# %%
#already replaced

# %% [markdown]
# ### Q3 Split Train/Test data 70:30 ratio( 1 Marks)
# ##### Hint:from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X1, Y1, test_size=0.30, random_state=1)

# %% [markdown]
# ### Q4 Build Random Forest Model( 1 Marks)
# #### Hint:from sklearn.ensemble import RandomForestClassifier using n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999

# %%
from sklearn.ensemble import RandomForestClassifier
Rf_Model=RandomForestClassifier(n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999)
Rf_Model.fit(X_train, Y_train)
y_pred= Rf_Model.predict(X_test)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)

# %% [markdown]
# ### Q5 Calculate Confusion Matrix and Accuracy score (1 Marks)
# ##### Hint: Use confusion_matrix and accuracy_score

# %%
from sklearn import metrics
print('Accuracy Score ',Rf_Model.score(X_test , Y_test))
print('Confusion Matrix \n', metrics.confusion_matrix(Y_test, y_pred))
# Out:
# Accuracy Score  0.7533333333333333
# Confusion Matrix
#  [[96  8]
#  [29 17]]

# %% [markdown]
# ### Q6 Show the list of the features importance( 1 Marks)

# %%
Features_imp = Rf_Model.feature_importances_
Features_imp

import pandas as pd
feature_importances = pd.DataFrame(Rf_Model.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
# array([0.06112767, 0.09933503, 0.04220622, 0.03213619, 0.08781319,
#        0.01903031, 0.01031466, 0.01547005, 0.02733667, 0.00861822,
#        0.04524331, 0.00781943, 0.02242615, 0.00983811, 0.01608262,
#        0.0124328 , 0.00589626, 0.0066611 , 0.02477934, 0.01205215,
#        0.0148942 , 0.00403403, 0.00211591, 0.01333561, 0.00223354,
#        0.00123962, 0.00630173, 0.01653981, 0.01204021, 0.00670521,
#        0.01345498, 0.01466532, 0.01872503, 0.0165422 , 0.01339339,
#        0.00652272, 0.01619654, 0.00300311, 0.00644314, 0.01427271,
#        0.00890242, 0.00960727, 0.0113141 , 0.01394668, 0.01460956,
#        0.01710441, 0.01046203, 0.01280681, 0.01705504, 0.00882843,
#        0.00969901, 0.0122814 , 0.01016244, 0.01371228, 0.01420415,
#        0.00074438, 0.01042982, 0.01328474, 0.01420996, 0.00388469,
#        0.00347189])
#                                                     importance
# credit_amount                                         0.099335
# age                                                   0.087813
# duration_in_month                                     0.061128
# account_check_status_no checking account              0.045243
# installment_as_income_perc                            0.042206
# present_res_since                                     0.032136
# account_check_status_< 0 DM                           0.027337
# purpose_car (new)                                     0.024779
# credit_history_critical account/ other credits ...    0.022426
# credits_this_bank                                     0.019030
# present_emp_since_... < 1 year                        0.018725
# property_real estate                                  0.017104
# other_installment_plans_none                          0.017055
# present_emp_since_1 <= ... < 4 years                  0.016542
# savings_... < 100 DM                                  0.016540
# personal_status_sex_female : divorced/separated...    0.016197
# credit_history_existing credits paid back duly ...    0.016083
# account_check_status_0 <= ... < 200 DM                0.015470
# purpose_domestic appliances                           0.014894
# present_emp_since_.. >= 7 years                       0.014665
# property_if not A121/A122 : car or other, not i...    0.014610
# personal_status_sex_male : single                     0.014273
# telephone_yes, registered under the customers n...    0.014210
# job_skilled employee / official                       0.014204
# property_if not A121 : building society savings...    0.013947
# job_management/ self-employed/ highly qualified...    0.013712
# savings_unknown/ no savings account                   0.013455
# present_emp_since_4 <= ... < 7 years                  0.013393
# purpose_radio/television                              0.013336
# telephone_none                                        0.013285
# ...                                                        ...
# credit_history_no credits taken/ all credits pa...    0.012433
# housing_own                                           0.012281
# purpose_car (used)                                    0.012052
# savings_100 <= ... < 500 DM                           0.012040
# other_debtors_none                                    0.011314
# property_unknown / no property                        0.010462
# job_unskilled - resident                              0.010430
# people_under_maintenance                              0.010315
# housing_rent                                          0.010162
# credit_history_delay in paying off in the past        0.009838
# housing_for free                                      0.009699
# other_debtors_guarantor                               0.009607
# other_debtors_co-applicant                            0.008902
# other_installment_plans_stores                        0.008828
# account_check_status_>= 200 DM / salary assignm...    0.008618
# credit_history_all credits at this bank paid ba...    0.007819
# savings_500 <= ... < 1000 DM                          0.006705
# purpose_business                                      0.006661
# present_emp_since_unemployed                          0.006523
# personal_status_sex_male : married/widowed            0.006443
# savings_.. >= 1000 DM                                 0.006302
# purpose_(vacation - does not exist?)                  0.005896
# purpose_education                                     0.004034
# foreign_worker_no                                     0.003885
# foreign_worker_yes                                    0.003472
# personal_status_sex_male : divorced/separated         0.003003
# purpose_repairs                                       0.002234
# purpose_furniture/equipment                           0.002116
# purpose_retraining                                    0.001240
# job_unemployed/ unskilled - non-resident              0.000744
#
# [61 rows x 1 columns]

# %%
from sklearn.metrics import r2_score
from rfpimp import permutation_importances

def r2(Rf_Model, X_train, Y_train):
    return r2_score(Y_train, Rf_Model.predict(X_train))

perm_imp_rfpimp = permutation_importances(Rf_Model, X_train, Y_train, r2)
perm_imp_rfpimp
# Out:
#                                                     Importance
# Feature
# age                                                   0.079545
# account_check_status_no checking account              0.066288
# purpose_car (new)                                     0.039773
# credit_amount                                         0.039773
# duration_in_month                                     0.039773
# credit_history_critical account/ other credits ...    0.026515
# installment_as_income_perc                            0.026515
# present_emp_since_... < 1 year                        0.013258
# present_emp_since_4 <= ... < 7 years                  0.013258
# personal_status_sex_female : divorced/separated...    0.000000
# personal_status_sex_male : divorced/separated         0.000000
# personal_status_sex_male : married/widowed            0.000000
# personal_status_sex_male : single                     0.000000
# property_unknown / no property                        0.000000
# other_debtors_co-applicant                            0.000000
# other_debtors_guarantor                               0.000000
# other_debtors_none                                    0.000000
# property_if not A121 : building society savings...    0.000000
# property_if not A121/A122 : car or other, not i...    0.000000
# property_real estate                                  0.000000
# other_installment_plans_none                          0.000000
# other_installment_plans_bank                          0.000000
# other_installment_plans_stores                        0.000000
# housing_for free                                      0.000000
# housing_own                                           0.000000
# housing_rent                                          0.000000
# job_management/ self-employed/ highly qualified...    0.000000
# job_skilled employee / official                       0.000000
# job_unemployed/ unskilled - non-resident              0.000000
# job_unskilled - resident                              0.000000
# ...                                                        ...
# telephone_yes, registered under the customers n...    0.000000
# foreign_worker_no                                     0.000000
# present_emp_since_unemployed                          0.000000
# savings_unknown/ no savings account                   0.000000
# present_emp_since_1 <= ... < 4 years                  0.000000
# present_emp_since_.. >= 7 years                       0.000000
# present_res_since                                     0.000000
# credits_this_bank                                     0.000000
# people_under_maintenance                              0.000000
# account_check_status_0 <= ... < 200 DM                0.000000
# account_check_status_< 0 DM                           0.000000
# account_check_status_>= 200 DM / salary assignm...    0.000000
# credit_history_all credits at this bank paid ba...    0.000000
# credit_history_delay in paying off in the past        0.000000
# credit_history_existing credits paid back duly ...    0.000000
# credit_history_no credits taken/ all credits pa...    0.000000
# purpose_(vacation - does not exist?)                  0.000000
# purpose_business                                      0.000000
# purpose_car (used)                                    0.000000
# purpose_domestic appliances                           0.000000
# purpose_education                                     0.000000
# purpose_furniture/equipment                           0.000000
# purpose_radio/television                              0.000000
# purpose_repairs                                       0.000000
# purpose_retraining                                    0.000000
# savings_.. >= 1000 DM                                 0.000000
# savings_... < 100 DM                                  0.000000
# savings_100 <= ... < 500 DM                           0.000000
# savings_500 <= ... < 1000 DM                          0.000000
# foreign_worker_yes                                    0.000000
#
# [61 rows x 1 columns]

# %% [markdown]
# ### Q7 K-fold cross-validation( 2 Marks)
# ##### k-fold cross validation( without stratification)
# ##### Usually k is set as 10-20 in practical settings, depends on data set size

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Use below values
num_folds = 10
seed = 77

# %%
#Validate the Random Forest model build above using k fold

# %%
# Evaluate using Cross Validation
from sklearn import model_selection

kfold = model_selection.KFold(n_splits=10, random_state=1)

# %%
results = model_selection.cross_val_score(Rf_Model, X1, Y1, scoring='neg_mean_squared_error', cv=kfold)
print("Mean Square Error: %.3f (%.3f)" % (-results.mean(), results.std()))
# Out:
# Mean Square Error: 0.242 (0.075)

# %%
cv=cross_val_score(Rf_Model, X_train, Y_train, cv=10)

# %%
#Calculate Mean score

# %%
cv.mean()
# Out:
# 0.7314285714285715

# %%
# Calculate score standard deviation using std()

# %%
cv.std()
# Out:
# 0.040808162448816306

# %% [markdown]
# # Q8 Print the confusion matrix( 1 Marks)

# %%
print(metrics.confusion_matrix(Y_test, y_pred))
# Out:
# [[96  8]
#  [29 17]]

# %% [markdown]
# # Q9.Classification accuracy:
# percentage of correct predictions and Calculate sensitivity (or True Positive Rate or Recall) and Precision.
# ( 1 Marks)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84       104
#            1       0.68      0.37      0.48        46
#
#    micro avg       0.75      0.75      0.75       150
#    macro avg       0.72      0.65      0.66       150
# weighted avg       0.74      0.75      0.73       150

# %% [markdown]
# # Q10.Plot Receiver Operating Characteristic (ROC) Curves( 1 Marks)

# %%
#Hint: Use roc_curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
fpr, tpr, _=roc_curve(Y_test, y_pred)

# %%
plt.plot(fpr,tpr)

# %% [markdown]
# ROC curve can help you to choose a threshold that balances sensitivity and specificity in a way that makes sense for your particular context

# %% [markdown]
# # Q11. Calculate AUC(the percentage of the ROC plot that is underneath the curve) - optional

# %%
print('AUC', roc_auc_score(Y_test, y_pred))
# Out:
# AUC 0.6463210702341138

# %% [markdown]
# ### Bootstrapping ( Bonus)
# ##### Given a dataset of size n, a bootstrap sample is created by sampling n instances uniformly from the data (with/without replacement)
# ##### Create a model with each bootstrap sample and validate it with the test set
# ##### Final result is calculated by averaging the accuracy of models

# %%
# Number of iterations for bootstrapping
bootstrap_iteration = 10
accuracy = []

# %%
from sklearn.utils import resample
from sklearn.metrics import accuracy_score

for i in range(bootstrap_iteration):
    X_, y_ = resample(X_train, Y_train)
    Rf_Model.fit(X_, y_)
    y_pred = Rf_Model.predict(X_test)
    
    acc = accuracy_score(y_pred, Y_test)
    accuracy.append(acc)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)

# %%
accuracy = np.array(accuracy)
print('Accuracy Score')
print('Avearge: ', accuracy.mean())
print('Standard deviation: ', accuracy.std())
# Out:
# Accuracy Score
# Avearge:  0.7446666666666666
# Standard deviation:  0.013012814197295431
